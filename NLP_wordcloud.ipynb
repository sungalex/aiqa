# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Wordcloud" data-toc-modified-id="Wordcloud-1">Wordcloud</a></span><ul class="toc-item"><li><span><a href="#KoNLPy-대한민국-법전(kolow)-WordCloud" data-toc-modified-id="KoNLPy-대한민국-법전(kolow)-WordCloud-1.1">KoNLPy 대한민국 법전(kolow) WordCloud</a></span></li><li><span><a href="#네이버-뉴스기사-WordCloud" data-toc-modified-id="네이버-뉴스기사-WordCloud-1.2">네이버 뉴스기사 WordCloud</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Wordcloud

# %% [markdown]
# ### KoNLPy 대한민국 법전(kolow) WordCloud

# %%
#!pip install konlpy

# %%
from konlpy.corpus import kolaw
from konlpy.tag import Kkma

# %%
corpus = kolaw.open(kolaw.fileids()[0]).read()
tagged = Kkma().pos(corpus)

# %%
#print(corpus)

# %%
len(tagged)
# Out:
# 10053

# %%
tagged
# Out:
# [('대한민국', 'NNG'),
#  ('헌법', 'NNG'),
#  ('유구', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ', 'ETD'),
#  ('역사', 'NNG'),
#  ('와', 'JC'),
#  ('전통', 'NNG'),
#  ('에', 'JKM'),
#  ('빛나', 'VV'),
#  ('는', 'ETD'),
#  ('우리', 'NNM'),
#  ('대하', 'VV'),
#  ('ㄴ', 'ETD'),
#  ('국민', 'NNG'),
#  ('은', 'JX'),
#  ('3', 'NR'),
#  ('·', 'SP'),
#  ('1', 'NR'),
#  ('운동', 'NNG'),
#  ('으로', 'JKM'),
#  ('건립', 'NNG'),
#  ('되', 'XSV'),
#  ('ㄴ', 'ETD'),
#  ('대한민국', 'NNG'),
#  ('임시', 'NNG'),
#  ('정부', 'NNG'),
#  ('의', 'JKG'),
#  ('법통', 'NNG'),
#  ('과', 'JC'),
#  ('불의', 'NNG'),
#  ('에', 'JKM'),
#  ('항거', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ', 'ETD'),
#  ('4', 'NR'),
#  ('·', 'SP'),
#  ('19', 'NR'),
#  ('민주', 'NNG'),
#  ('이념', 'NNG'),
#  ('을', 'JKO'),
#  ('계승', 'NNG'),
#  ('하', 'XSV'),
#  ('고', 'ECE'),
#  (',', 'SP'),
#  ('조국', 'NNG'),
#  ('의', 'JKG'),
#  ('민주', 'NNG'),
#  ('개혁', 'NNG'),
#  ('과', 'JKM'),
#  ('평화적', 'NNG'),
#  ('통일', 'NNG'),
#  ('의', 'JKG'),
#  ('사명', 'NNG'),
#  ('에', 'JKM'),
#  ('입각', 'NNG'),
#  ('하', 'XSV'),
# ...

# %%
result = [_[0] for _ in tagged if len(_[0]) > 1 and not (_[1].startswith("J") or _[0].startswith("ㄴ"))]    # J* : 조사,  "L"으로 시작하는 종결어미 제외

# %%
result
# Out:
# ['대한민국',
#  '헌법',
#  '유구',
#  '역사',
#  '전통',
#  '빛나',
#  '우리',
#  '대하',
#  '국민',
#  '운동',
#  '건립',
#  '대한민국',
#  '임시',
#  '정부',
#  '법통',
#  '불의',
#  '항거',
#  '19',
#  '민주',
#  '이념',
#  '계승',
#  '조국',
#  '민주',
#  '개혁',
#  '평화적',
#  '통일',
#  '사명',
#  '입각',
#  '정의',
#  '인도',
#  '동포애',
#  '민족',
#  '단결',
#  '공고히',
#  '모든',
#  '사회적',
#  '폐습',
#  '불의',
#  '타파',
#  '자율',
#  '조화',
#  '바탕',
#  '자유',
#  '민주적',
#  '기본',
#  '질서',
#  '더욱',
#  '확고히',
#  '하여',
#  '정치',
#  '경제',
#  '사회',
#  '문화',
#  '모든',
#  '영역',
#  '어서',
#  '각인',
#  '기회',
#  '균등',
#  '능력',
#  '최고',
#  '도로',
#  '발휘',
#  '자유',
#  '권리',
#  '따르',
#  '책임',
#  '의무',
#  '완수',
#  '하여',
#  '국민',
#  '생활',
#  '균등',
#  '향상',
#  '기하',
#  '항구적',
#  '세계',
#  '평화',
#  '인류',
#  '공영',
#  '이바지',
#  '우리',
#  '우리',
#  '자손',
#  '안전',
#  '자유',
#  '행복',
#  '영원히',
#  '확보',
#  '다짐',
#  '면서',
#  '1948',
#  '12',
#  '제정',
#  '걸치',
#  '개정',
#  '헌법',
#  '이제',
#  '국회',
#  '의결',
#  '거치',
#  '국민',
#  '투표',
#  '의하',
#  '개정',
#  '대한민국',
#  '민주',
#  '공화국',
# ...

# %%
len(set(result))
# Out:
# 1086

# %%
#!pip install nltk

from nltk import Text

# %%
textObj = Text(result)

# %%
textObj.vocab().most_common(20)
# Out:
# [('법률', 121),
#  ('정하', 88),
#  ('대통령', 84),
#  ('의하', 83),
#  ('국가', 73),
#  ('헌법', 69),
#  ('국민', 69),
#  ('또는', 69),
#  ('국회', 55),
#  ('아니하', 53),
#  ('관하', 53),
#  ('회의', 42),
#  ('모든', 37),
#  ('위하', 33),
#  ('가지', 32),
#  ('필요', 31),
#  ('여야', 31),
#  ('위원', 31),
#  ('국무', 30),
#  ('기타', 26)]

# %%
#!pip install wordcloud

# %%
from wordcloud import WordCloud

# %%
termList = textObj.vocab()

# %%
path = "/Libaray/Fonts/AppleGothic.ttf"    # for MAC
#path = "C:/Windows/Fonts/malgun.ttf"       # for Windows

wc = WordCloud(font_path=path, max_words=500, background_color="white")
wc.generate_from_frequencies(termList)
wc.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x13FD81BE0>

# %%
wc_array = wc.to_array()
type(wc_array)
# Out:
# numpy.ndarray

# %% [markdown]
# ### 네이버 뉴스기사 WordCloud

# %%
# 네이버 뉴스기사
import os

corpus = ""

for _ in os.listdir("./naver_news"):
    if _.endswith(".txt") and _.startswith("00"):   # 00~05로 시작함(기사 분류 기호)
        with open("./naver_news/"+_, encoding='UTF8') as f:
            corpus += f.read()

# %%
len(corpus)
# Out:
# 23692

# %%
tagged = Kkma().nouns(corpus)

# %%
from collections import defaultdict   # Dictionary 자료형
nounList = defaultdict(int)

# %%
for _ in tagged:
    nounList[_] += 1

# %%
wc.generate_from_frequencies(nounList)
wc.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x13FD47860>
