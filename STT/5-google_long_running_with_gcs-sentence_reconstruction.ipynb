# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Google-Cloud-Speech-to-Text-API-Long_Running-example" data-toc-modified-id="Google-Cloud-Speech-to-Text-API-Long_Running-example-1">Google Cloud Speech-to-Text API Long_Running example</a></span></li></ul></div>

# %% [markdown]
# # Google Cloud Speech-to-Text API Long_Running example

# %% [markdown]
# - 긴 오디오 파일을 비동기 방식으로 처리하는 샘플
# - **오디오 파일은 Google Cloud Storage에 업로드 후 사용**
# - **오디오 파일 크기 제한은 없으나, 전체 파일을 모두 변환 후 응답을 받을 수 있음**
# - https://cloud.google.com/speech-to-text/docs/async-recognize
# - https://cloud.google.com/speech-to-text/docs/async-time-offsets
# - Google Cloud Storage 설정 방법 : https://cloud.google.com/storage/docs/quickstart-console

# %%
"""Transcribe the given audio file asynchronously and output the word time offsets."""
from google.cloud import speech
from google.cloud.speech import enums
from google.cloud.speech import types

client = speech.SpeechClient()

gcs_uri = "gs://aiqa-stt/witch_hunt_2_online-audio-converter.com_16000.wav"

audio = types.RecognitionAudio(uri=gcs_uri)
config = types.RecognitionConfig(
    encoding=enums.RecognitionConfig.AudioEncoding.LINEAR16,
    sample_rate_hertz=16000,
    language_code='ko-KR',
    enable_automatic_punctuation=True,
    enable_word_time_offsets=True)

operation = client.long_running_recognize(config, audio)

# %%
print('Waiting for operation to complete...')
response = operation.result(timeout=360)
print('operation complete !!!')
# Out:
# Waiting for operation to complete...
# operation complete !!!

# %%
type(response)
# Out:
# google.cloud.speech_v1.types.LongRunningRecognizeResponse

# %%
response.results[0]
# Out:
# alternatives {
#   transcript: "\354\227\260\354\230\210\354\235\270 \354\244\221\354\227\220\354\204\234\353\217\204 \355\225\231\352\265\220 \354\225\210\353\202\264\353\260\251\354\206\241\354\235\204 \353\255\230 \355\225\230\352\262\214 \353\220\240 \354\235\274\354\235\264 \354\203\235\352\270\260\353\212\224 \353\247\211 \354\240\204\354\240\204\352\270\215\352\270\215\355\225\230\352\263\240 \354\226\230\352\270\260\355\225\264\354\204\234 \354\242\200 \353\271\274 \353\213\254\353\235\274 \353\202\230\353\212\224 \352\260\231\354\235\264 \354\247\200\352\270\210 \353\201\235\352\271\214\354\247\200 \352\267\270\353\237\260 \352\261\260 \354\241\260\354\213\254\355\225\230\353\212\224 \352\262\275\354\232\260\352\260\200 \354\236\210\352\263\240 \354\226\264\353\226\244 \353\266\204\353\223\244\354\235\200 \353\230\220 \354\262\234\354\227\260\353\215\225\354\212\244\353\237\275\352\262\214 \354\242\213\354\235\200 \352\267\200\354\260\256\352\263\240 \355\233\214\353\245\255\355\225\230\352\262\214 \353\214\200\354\262\230\355\225\230\353\212\224 \353\266\204\353\223\244\353\217\204 \352\263\204\354\213\234\353\215\224\353\235\274\352\265\254\354\232\224. \354\230\210 \354\226\264\353\225\214\354\232\224 \355\225\250\352\273\230 \353\260\251\354\206\241\354\227\220 \353\202\230\354\231\200\354\232\224 \353\255\220 \354\230\210\354\240\204\354\227\220 \354\236\240\352\271\220 \354\235\264\353\240\207\352\262\214 
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 8
#       nanos: 800000000
#     }
#     word: "\354\226\230\352\270\260\355\225\264\354\204\234"
#   }
#   words {
#     start_time {
#       seconds: 8
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 9
#       nanos: 500000000
#     }
#     word: "\354\242\200"
#   }
#   words {
#     start_time {
#       seconds: 9
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 9
#       nanos: 700000000
#     }
#     word: "\353\271\274"
#   }
#   words {
#     start_time {
#       seconds: 9
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 10
#     }
#     word: "\353\213\254\353\235\274"
#   }
#   words {
#     start_time {
#       seconds: 10
#     }
#     end_time {
#       seconds: 10
#       nanos: 900000000
#     }
#     word: "\353\202\230\353\212\224"
#   }
#   words {
#     start_time {
#       seconds: 10
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 11
#       nanos: 100000000
#     }
#     word: "\352\260\231\354\235\264"
#   }
#   words {
#     start_time {
#       seconds: 11
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 11
#       nanos: 400000000
#     }
#     word: "\354\247\200\352\270\210"
#   }
#   words {
#     start_time {
#       seconds: 11
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 13
#     }
#     word: "\353\201\235\352\271\214\354\247\200"
#   }
#   words {
#     start_time {
#       seconds: 13
#     }
#     end_time {
#       seconds: 13
#       nanos: 200000000
#     }
#     word: "\352\267\270\353\237\260"
#   }
#   words {
#     start_time {
#       seconds: 13
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 13
#       nanos: 300000000
#     }
#     word: "\352\261\260"
#   }
#   words {
#     start_time {
#       seconds: 13
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 13
#       nanos: 700000000
#     }
#     word: "\354\241\260\354\213\254\355\225\230\353\212\224"
#   }
#   words {
#     start_time {
#       seconds: 13
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 14
#     }
#     word: "\352\262\275\354\232\260\352\260\200"
#   }
#   words {
#     start_time {
#       seconds: 14
#     }
#     end_time {
#       seconds: 14
#       nanos: 100000000
#     }
#     word: "\354\236\210\352\263\240"
#   }
#   words {
#     start_time {
#       seconds: 14
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 14
#       nanos: 700000000
#     }
#     word: "\354\226\264\353\226\244"
#   }
#   words {
#     start_time {
#       seconds: 14
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 15
#       nanos: 800000000
#     }
#     word: "\353\266\204\353\223\244\354\235\200"
#   }
#   words {
#     start_time {
#       seconds: 15
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 16
#     }
#     word: "\353\230\220"
#   }
#   words {
#     start_time {
#       seconds: 16
#     }
#     end_time {
#       seconds: 17
#       nanos: 700000000
#     }
#     word: "\354\262\234\354\227\260\353\215\225\354\212\244\353\237\275\352\262\214"
#   }
#   words {
#     start_time {
#       seconds: 17
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 18
#       nanos: 500000000
#     }
#     word: "\354\242\213\354\235\200"
#   }
#   words {
#     start_time {
#       seconds: 18
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 19
#       nanos: 200000000
#     }
#     word: "\352\267\200\354\260\256\352\263\240"
#   }
#   words {
#     start_time {
#       seconds: 19
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 20
#       nanos: 700000000
#     }
#     word: "\355\233\214\353\245\255\355\225\230\352\262\214"
#   }
#   words {
#     start_time {
#       seconds: 20
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 21
#       nanos: 400000000
#     }
#     word: "\353\214\200\354\262\230\355\225\230\353\212\224"
#   }
#   words {
#     start_time {
#       seconds: 21
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 21
#       nanos: 800000000
#     }
#     word: "\353\266\204\353\223\244\353\217\204"
#   }
#   words {
#     start_time {
#       seconds: 21
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 22
#       nanos: 200000000
#     }
#     word: "\352\263\204\354\213\234\353\215\224\353\235\274\352\265\254\354\232\224."
#   }
#   words {
#     start_time {
#       seconds: 22
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 24
#       nanos: 600000000
#     }
#     word: "\354\230\210"
#   }
#   words {
#     start_time {
#       seconds: 24
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 25
#       nanos: 400000000
#     }
#     word: "\354\226\264\353\225\214\354\232\224"
#   }
#   words {
#     start_time {
#       seconds: 25
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 27
#       nanos: 200000000
#     }
#     word: "\355\225\250\352\273\230"
#   }
#   words {
#     start_time {
#       seconds: 27
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 28
#     }
#     word: "\353\260\251\354\206\241\354\227\220"
#   }
#   words {
#     start_time {
#       seconds: 28
#     }
#     end_time {
#       seconds: 28
#       nanos: 400000000
#     }
#     word: "\353\202\230\354\231\200\354\232\224"
#   }
#   words {
#     start_time {
#       seconds: 28
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 28
#       nanos: 500000000
#     }
#     word: "\353\255\220"
#   }
#   words {
#     start_time {
#       seconds: 28
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 28
#       nanos: 700000000
#     }
#     word: "\354\230\210\354\240\204\354\227\220"
#   }
#   words {
#     start_time {
#       seconds: 28
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 29
#       nanos: 300000000
#     }
#     word: "\354\236\240\352\271\220"
#   }
#   words {
#     start_time {
#       seconds: 29
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 29
#       nanos: 500000000
#     }
#     word: "\354\235\264\353\240\207\352\262\214"
#   }
#   words {
#     start_time {
#       seconds: 29
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 30
#     }
#     word: "\354\202\254\352\262\274\353\215\230"
#   }
#   words {
#     start_time {
#       seconds: 30
#     }
#     end_time {
#       seconds: 31
#       nanos: 100000000
#     }
#     word: "\352\267\270\353\237\274"
#   }
#   words {
#     start_time {
#       seconds: 31
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 33
#       nanos: 200000000
#     }
#     word: "1\354\233\224"
#   }
#   words {
#     start_time {
#       seconds: 33
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 33
#       nanos: 600000000
#     }
#     word: "\354\202\254\353\236\214\354\235\270\353\215\260"
#   }
#   words {
#     start_time {
#       seconds: 33
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 34
#     }
#     word: "\352\260\221\354\236\220\352\270\260"
#   }
#   words {
#     start_time {
#       seconds: 34
#     }
#     end_time {
#       seconds: 38
#       nanos: 200000000
#     }
#     word: "\353\247\216\354\235\264"
#   }
#   words {
#     start_time {
#       seconds: 38
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 38
#       nanos: 600000000
#     }
#     word: "\355\236\230\353\223\244\354\243\240"
#   }
#   words {
#     start_time {
#       seconds: 38
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 40
#       nanos: 700000000
#     }
#     word: "\352\267\270\353\203\245"
#   }
#   words {
#     start_time {
#       seconds: 40
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 41
#       nanos: 300000000
#     }
#     word: "\354\241\260\352\270\210"
#   }
#   words {
#     start_time {
#       seconds: 41
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 41
#       nanos: 400000000
#     }
#     word: "\354\225\210"
#   }
#   words {
#     start_time {
#       seconds: 41
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 41
#       nanos: 900000000
#     }
#     word: "\353\247\236\353\212\224\352\265\254\353\202\230"
#   }
#   words {
#     start_time {
#       seconds: 41
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 42
#       nanos: 400000000
#     }
#     word: "\354\204\270\354\233\214\354\247\204"
#   }
#   words {
#     start_time {
#       seconds: 42
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 42
#       nanos: 800000000
#     }
#     word: "\352\260\200\353\262\274\354\232\264"
#   }
#   words {
#     start_time {
#       seconds: 42
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 43
#       nanos: 100000000
#     }
#     word: "\352\264\200\352\263\204\353\212\224"
#   }
#   words {
#     start_time {
#       seconds: 43
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 43
#       nanos: 800000000
#     }
#     word: "\352\267\270\353\236\230"
#   }
#   words {
#     start_time {
#       seconds: 43
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 44
#       nanos: 200000000
#     }
#     word: "\354\232\260\353\246\254"
#   }
#   words {
#     start_time {
#       seconds: 44
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 44
#       nanos: 400000000
#     }
#     word: "\354\235\264\353\252\250"
#   }
#   words {
#     start_time {
#       seconds: 44
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 45
#       nanos: 200000000
#     }
#     word: "\354\271\234\352\265\254\353\212\224"
#   }
#   words {
#     start_time {
#       seconds: 45
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 45
#       nanos: 500000000
#     }
#     word: "\352\263\204\354\206\215"
#   }
#   words {
#     start_time {
#       seconds: 45
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 45
#       nanos: 900000000
#     }
#     word: "\354\247\200\353\202\264\354\236\220"
#   }
#   words {
#     start_time {
#       seconds: 45
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 46
#       nanos: 400000000
#     }
#     word: "\352\267\274\353\215\260"
#   }
#   words {
#     start_time {
#       seconds: 46
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 46
#       nanos: 700000000
#     }
#     word: "\354\240\225\353\247\220"
#   }
#   words {
#     start_time {
#       seconds: 46
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 47
#       nanos: 100000000
#     }
#     word: "\353\247\211"
#   }
#   words {
#     start_time {
#       seconds: 47
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 48
#       nanos: 500000000
#     }
#     word: "\354\213\270\354\232\260\352\263\240"
#   }
#   words {
#     start_time {
#       seconds: 48
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 48
#       nanos: 700000000
#     }
#     word: "\353\247\211"
#   }
#   words {
#     start_time {
#       seconds: 48
#       nanos: 700000000
#     }
#     end_time {
#       seconds: 49
#       nanos: 100000000
#     }
#     word: "\352\267\270\353\237\254\353\213\244\352\260\200"
#   }
#   words {
#     start_time {
#       seconds: 49
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 50
#     }
#     word: "\354\226\264\354\251\224"
#   }
#   words {
#     start_time {
#       seconds: 50
#     }
#     end_time {
#       seconds: 50
#       nanos: 200000000
#     }
#     word: "\354\210\230"
#   }
#   words {
#     start_time {
#       seconds: 50
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 50
#       nanos: 500000000
#     }
#     word: "\354\227\206\353\212\224"
#   }
#   words {
#     start_time {
#       seconds: 50
#       nanos: 500000000
#     }
#     end_time {
#       seconds: 50
#       nanos: 800000000
#     }
#     word: "\354\235\264\354\234\240\353\241\234"
#   }
#   words {
#     start_time {
#       seconds: 50
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 51
#       nanos: 600000000
#     }
#     word: "\355\227\244\354\226\264\354\241\214\354\234\274\353\251\264"
#   }
#   words {
#     start_time {
#       seconds: 51
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 52
#     }
#     word: "\353\202\230\354\244\221\354\227\220"
#   }
#   words {
#     start_time {
#       seconds: 52
#     }
#     end_time {
#       seconds: 52
#       nanos: 300000000
#     }
#     word: "\353\247\214\353\202\254\354\235\204"
#   }
#   words {
#     start_time {
#       seconds: 52
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 52
#       nanos: 400000000
#     }
#     word: "\353\225\214"
#   }
#   words {
#     start_time {
#       seconds: 52
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 53
#       nanos: 200000000
#     }
#     word: "\354\271\234\352\265\254"
#   }
#   words {
#     start_time {
#       seconds: 53
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 54
#       nanos: 300000000
#     }
#     word: "\354\236\230"
#   }
#   words {
#     start_time {
#       seconds: 54
#       nanos: 300000000
#     }
#     end_time {
#       seconds: 54
#       nanos: 600000000
#     }
#     word: "\354\247\200\353\202\264\353\212\224\352\260\200"
#   }
#   words {
#     start_time {
#       seconds: 54
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 55
#       nanos: 400000000
#     }
#     word: "\354\235\264\353\240\207\352\262\214"
#   }
#   words {
#     start_time {
#       seconds: 55
#       nanos: 400000000
#     }
#     end_time {
#       seconds: 55
#       nanos: 800000000
#     }
#     word: "\353\220\230\353\212\224"
#   }
#   words {
#     start_time {
#       seconds: 55
#       nanos: 800000000
#     }
#     end_time {
#       seconds: 55
#       nanos: 900000000
#     }
#     word: "\352\261\260"
#   }
#   words {
#     start_time {
#       seconds: 55
#       nanos: 900000000
#     }
#     end_time {
#       seconds: 56
#       nanos: 100000000
#     }
#     word: "\354\235\264\354\203\201\355\225\234"
#   }
#   words {
#     start_time {
#       seconds: 56
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 56
#       nanos: 200000000
#     }
#     word: "\352\261\260"
#   }
#   words {
#     start_time {
#       seconds: 56
#       nanos: 200000000
#     }
#     end_time {
#       seconds: 56
#       nanos: 600000000
#     }
#     word: "\354\225\204\353\213\214\352\260\200\354\232\224"
#   }
#   words {
#     start_time {
#       seconds: 56
#       nanos: 600000000
#     }
#     end_time {
#       seconds: 57
#       nanos: 100000000
#     }
#     word: "\354\236\230"
#   }
#   words {
#     start_time {
#       seconds: 57
#       nanos: 100000000
#     }
#     end_time {
#       seconds: 57
#       nanos: 600000000
#     }
#     word: "\354\247\200\353\202\264\353\212\224\352\260\200?"
#   }
# }

# %%
response.results[0].alternatives[0].transcript
# Out:
# '연예인 중에서도 학교 안내방송을 뭘 하게 될 일이 생기는 막 전전긍긍하고 얘기해서 좀 빼 달라 나는 같이 지금 끝까지 그런 거 조심하는 경우가 있고 어떤 분들은 또 천연덕스럽게 좋은 귀찮고 훌륭하게 대처하는 분들도 계시더라구요. 예 어때요 함께 방송에 나와요 뭐 예전에 잠깐 이렇게 사겼던 그럼 1월 사람인데 갑자기 많이 힘들죠 그냥 조금 안 맞는구나 세워진 가벼운 관계는 그래 우리 이모 친구는 계속 지내자 근데 정말 막 싸우고 막 그러다가 어쩔 수 없는 이유로 헤어졌으면 나중에 만났을 때 친구 잘 지내는가 이렇게 되는 거 이상한 거 아닌가요 잘 지내는가?'

# %%
response.results[0].alternatives[0].confidence
# Out:
# 0.8978368639945984

# %%
print("start_time:", response.results[0].alternatives[0].words[0].start_time.seconds + \
      response.results[0].alternatives[0].words[0].start_time.nanos * 1e-9)
# Out:
# start_time: 0.0

# %%
print("end_time:", response.results[0].alternatives[0].words[-1].end_time.seconds + \
     response.results[0].alternatives[0].words[-1].end_time.seconds * 1e-9)
# Out:
# end_time: 57.000000057

# %%
for result in response.results:
    alternative = result.alternatives[0]
    print(u'Transcript: {}'.format(alternative.transcript))
    print('Confidence: {}'.format(alternative.confidence))

    start_time = alternative.words[0].start_time
    end_time = alternative.words[-1].end_time
    print('start_time: {} ~ end_time: {}'.format(start_time.seconds + start_time.nanos * 1e-9, \
            end_time.seconds + end_time.nanos * 1e-9))
    print()
# Out:
# Confidence: 0.9124661684036255
# start_time: 641.4 ~ end_time: 701.3
#
# Transcript: 주면 경우도 많아요. 추워 가지고 줄 거야 줄 거야 오늘은 우리 눈 치우러 가야 돼서요 나가기 전에 날씨 확인하고 가방 안에 쓸데없는 거 있으면 빼 놓을게요. 진짜 남녀평등 정말 완벽한 얘기하는게 알게 됐네요. 남자들이 하는 행동 중에서 보기 싫다 관한 그 사람들 있잖아요 문을 열어주는 의자를 빼서 넣어 준대 영화를 너무 많이 본 거 있어 그거 생각하면 그런 거예요 상대한테 내가 지금 뭐를 해 줬다고이 사람이 못 느끼게 해주는게 아까 내놓으라고 생각하는데 뭐야 친구가.
# Confidence: 0.9128856062889099
# start_time: 701.4 ~ end_time: 747.5
#
# Transcript: 생리 첫날이네요 보통 언제 생리첫날 이면은 변비가 깨지거든요. 지금 화장실에 갔을때 TV 리모콘이 볼륨을 높여 준다든가.
# Confidence: 0.8129894137382507
# start_time: 748.2 ~ end_time: 758.2
#
# Transcript:  이런 거 이런 거 봐봐 이렇게 되는 거야? 근데 저는 라이트로 봐도 괜찮을 것 같아요. 특별한 우리 성시경씨 같은 남자들도 물론 있지만 해 나 새 남자들은 아니 곤경에 처해 있으면 그 여자가 그거를 그린 라이트라고 오해하고 막 접근해서 좀 힘든 걸 좀 다 했으면 좋겠다.
# Confidence: 0.9159653782844543
# start_time: 758.8 ~ end_time: 794.7

# %%
# CSV 파일로 저장
import csv

with open('text/마녀사냥_Transcribe.csv', 'w', encoding='utf-8', newline='') as f:
    wr = csv.writer(f)
    wr.writerow(["start_time", "end_time", "transcript"])
    for result in response.results:
        alternative = result.alternatives[0]
        start_time = alternative.words[0].start_time.seconds + alternative.words[0].start_time.nanos * 1e-9
        end_time = alternative.words[-1].end_time.seconds + alternative.words[-1].end_time.nanos * 1e-9
        wr.writerow([start_time, end_time, alternative.transcript])

# %%
corpus = ""
for result in response.results:
    alternative = result.alternatives[0]
    corpus = corpus + alternative.transcript + " "

# %%
# !pip install nltk
import nltk
from nltk.tokenize import punkt
from nltk.tokenize import sent_tokenize

# %%
sentence = sent_tokenize(corpus)
len(sentence)
# Out:
# 38

# %%
sentence
# Out:
# ['연예인 중에서도 학교 안내방송을 뭘 하게 될 일이 생기는 막 전전긍긍하고 얘기해서 좀 빼 달라 나는 같이 지금 끝까지 그런 거 조심하는 경우가 있고 어떤 분들은 또 천연덕스럽게 좋은 귀찮고 훌륭하게 대처하는 분들도 계시더라구요.',
#  '예 어때요 함께 방송에 나와요 뭐 예전에 잠깐 이렇게 사겼던 그럼 1월 사람인데 갑자기 많이 힘들죠 그냥 조금 안 맞는구나 세워진 가벼운 관계는 그래 우리 이모 친구는 계속 지내자 근데 정말 막 싸우고 막 그러다가 어쩔 수 없는 이유로 헤어졌으면 나중에 만났을 때 친구 잘 지내는가 이렇게 되는 거 이상한 거 아닌가요 잘 지내는가?',
#  '좋아했던 사람 많은가 교통신호가 잘 안 되는 거예요 그냥 쉽게 쉽게 만나는 스타일이 수도 있을 거 같아요 근데 문제는이 여자가 딴 걸 못 해 그렇지 이런 데서 하는 거야이 말을 할 때 얼마나 많은게 맞는 얘기고 뭐 하는 얘기 아니야 지금 방송 생동하게 샘동이 헤어졌어요 상대방이 다시 연락 온 적 있어요 혹시 진짜 미친 거 같아 밤에 술 마시고 전화한 거야.',
#  '그러면서 막 약속할 수 없는 말들을 잡고 문자로 보내는 거예요 다음날 되면 꼭 해야 하거든 당연히 병원에 있어요 좀 받아 본 적이 있지요 기분이 되게 집 하지요 오빠 어디야 뭐 해 보고 싶어서 전화했지.',
#  '그렇지요 마이크가 어디야 씨가 그냥 지금 만나서 오늘 같이 있자 뭐 이런 느낌이었어요 그쵸 가지고 이렇게 만나서 세포를 풀 수 있겠죠 근데 없어 의미가 없고 하루 지나고 난 술도 깨고 나면 다 사라질 모든 탭 다 그런 경험 있지 않냐 술 취해서 전화한 거 그다음에 하는데 발신 열 두 번인데 0초 0초 0초 0초 12분 있잖아요 한참 술 먹었을 때 아침에 일어나자마자 처음 했던 거 핸드폰 확인했어요 누구한테 전화해 뜬지 누구한테 문자 보냈는지 그리고 무슨 사진 지르는지 사진도 찍어야 아니면 그냥 기억안날때 있는데 무슨 사진인지 술 먹고 싶네요.',
#  '아니 근데 이렇게 보고 놀란 적이 있지요 왜 이런 사진 겁나게 왜 그런 거 아니지?',
#  '그 다음날 잘 기억은 안 나고 그렇군요 지금 그러면은 사람들한테 많은 사람을 봤잖아요 주위에서 노인네처럼 사람들 많아요 적은 있더라고요 뭐라고 하지 말라고 아 그런 거 같아요.',
#  '술을 먹으면 조금 거칠어지는 느낌이 있다는 예전에 주소 좀 있었더라고요.',
#  '그렇겠죠 호주가 청정지역인데 호텔 쓰레기라고 그러더라고 너무 보고 싶어 빨리 하자.',
#  '저는 속에 사람들이 얘기하는 쿨하게 헤어지는 것 불가능하다고 아름다운 이별 그쵸 미드가 사람들을 많이 망쳐놨어 그래요 뭐 연락을 한다고 10시 근데 그거를 굳이 내 앞에서 할 필요 없다고 생각해 만약에 내가 아끼는 사람이 그로 인해 스트레스 받는다고 얘기했으면 굳이 그 앞에서 어 그래 갈게 그 거는 별로 그래 친구 가게 인정해 줄게 내 앞에서 통화 하지 말아 줘 내가 마음이 너무 아파 그래서 너는 여자도 좀 더 조심하려고 하고 그런 그렇게 돼야 되는게 좋은 거 아니네 휴게소 오늘 너의 목소리가 들려 홈페이지와 페이스북 열려 있습니다.',
#  '많이 아들로 고민하는 남자분들 여자분들 이야기 없어요 성심성의껏 얘기 나누도록 하겠습니다 사랑은 용기있는자가 쟁취한다 이거 옛날 말입니다 사람 그린라이트를 이거는 제가 갑니다.',
#  '알송 어려운 호감의 신호들을 저희가 놓치지않고 알려 드립니다.',
#  '그러면 정말 관심이 없고 내가 싫어하는 애 물도 들어줄게 할 수 있는 편이에요.',
#  '그런 사람 말고 자기가 싫으면 아무것도 안 해 줍니다.',
#  '여성분들 - 있지 않습니까?',
#  '이게 진짜 무겁습니다.',
#  '2만 원 크기인데 어떻게 무겁지 나는 마음이 너무 너무 더운데 그 밴드를 정도면은 당연히 어떤 마음이 있어서 제 입장 생각해 보면 울었거든요 저는 연애하면서 가방 들어 본 적 한 번도 없어요 저 그거 남자 하려고 안 자고 있으면 우리 어머니도 한국 최고 220 어떤게 남자들은 자기여자친구 핸드폰 들고 다니는게 맨날 거 말고 저는 관심녀 있다면 이렇게 할 수 있다고 생각해 그러면 가끔 다른 얘기긴 하지만 보기 싫다는 화장실 앞에서 이렇게 들고 있고 이런 걸 얘기하는 거야 밖에서 걸어 다닐 때 위해서 가는 거 아니잖아요 위에서 만들었고 만약에 그런 일이 있다면 원주 남자한테 무슨 색 가방 들고 나올 건지 남자 신발이나 밴드 좀 맞춰 줄 수 있겠니?',
#  '이왕이면 갈 거면 그렇게 해야 되는데 이게 아니잖아, 근데 그냥 몸에 이렇게 매너가 되어 있는 사람 있잖아요 아까 전에 전화 안 했잖아 좀 그렇게 해야 된다는 강박이 좀 있었던 거 같아 어렸을 때도 회식을 할 때를 들어 진짜 추운 날 감정이 없어 내가 남잔데요 오빠하고 덜덜 덜덜 떨면서 벗어 주는게 아닌가요 이거 이상해요 날씨 먼저 퍼거 집에나 가야 되는 거 아니야 아니 다 드셨어요 저는 그렇게 해서 우리 어머니 어렸을 때 무조건 여주에서 문 열어 주고 응 그렇게 해야 되는데 요즘 여자들은 남자들하고 똑같은 시상으로 받고 싶으니까 이렇게 재킷.',
#  '주면 경우도 많아요.',
#  '추워 가지고 줄 거야 줄 거야 오늘은 우리 눈 치우러 가야 돼서요 나가기 전에 날씨 확인하고 가방 안에 쓸데없는 거 있으면 빼 놓을게요.',
#  '진짜 남녀평등 정말 완벽한 얘기하는게 알게 됐네요.',
#  '남자들이 하는 행동 중에서 보기 싫다 관한 그 사람들 있잖아요 문을 열어주는 의자를 빼서 넣어 준대 영화를 너무 많이 본 거 있어 그거 생각하면 그런 거예요 상대한테 내가 지금 뭐를 해 줬다고이 사람이 못 느끼게 해주는게 아까 내놓으라고 생각하는데 뭐야 친구가.',
#  '생리 첫날이네요 보통 언제 생리첫날 이면은 변비가 깨지거든요.',
#  '지금 화장실에 갔을때 TV 리모콘이 볼륨을 높여 준다든가.',
#  '이런 거 이런 거 봐봐 이렇게 되는 거야?',
#  '근데 저는 라이트로 봐도 괜찮을 것 같아요.',
#  '특별한 우리 성시경씨 같은 남자들도 물론 있지만 해 나 새 남자들은 아니 곤경에 처해 있으면 그 여자가 그거를 그린 라이트라고 오해하고 막 접근해서 좀 힘든 걸 좀 다 했으면 좋겠다.']

# %%
# 스크립트 만 Text 파일로 저장
with open('text/마녀사냥_Transcribe.txt', 'w', encoding='utf-8', newline='') as f:
    for sent in sentence:
        f.write(sent + "\n")
