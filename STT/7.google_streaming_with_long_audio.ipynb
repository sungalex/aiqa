# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Google-Cloud-Speech-to-Text-API-Streaming-example" data-toc-modified-id="Google-Cloud-Speech-to-Text-API-Streaming-example-1">Google Cloud Speech-to-Text API Streaming example</a></span></li></ul></div>

# %% [markdown]
# # Google Cloud Speech-to-Text API Streaming example

# %% [markdown]
# - 1분 이상의 긴 오디오 파일을 Streaming 방식으로 처리하는 샘플
# - https://cloud.google.com/speech-to-text/docs/streaming-recognize
# - google.cloud.speech.SpeechClient().**streaming_recognize(streaming_config, requests)**
# - **Audio file size limit : 10M bytes** => 10M 이상의 파일을 처리하기 위해 wave file을 10M 이하 크기로 잘라서 변환하도록 개선

# %%
#!pip install pyaudio

# %%
import pyaudio
import wave
import os
import io
import csv

import numpy as np

from nltk.tokenize import sent_tokenize, word_tokenize

# for speaker_diarization (use speech_v1p1beta1)
from google.cloud import speech_v1p1beta1 as speech
from google.cloud.speech_v1p1beta1 import enums
from google.cloud.speech_v1p1beta1 import types

# %%
def transcribe_streaming(stream_file):
    """Streams transcription of the given audio file."""
    words_with_tag = []
    transcripts = []

    client = speech.SpeechClient()

    with io.open(stream_file, 'rb') as audio_file:
        content = audio_file.read()

    # In practice, stream should be a generator yielding chunks of audio data.
    stream = [content]

    requests = (types.StreamingRecognizeRequest(audio_content=chunk)
                for chunk in stream)

    config = types.RecognitionConfig(
        encoding=enums.RecognitionConfig.AudioEncoding.LINEAR16,
        sample_rate_hertz=16000,
        language_code='ko-KR',
        enable_automatic_punctuation=True,
        enable_word_time_offsets=True,
        enable_speaker_diarization=True,    # 한국어 지원 안됨 (speaker_tag가 모두 동일인으로 분류됨)
        diarization_speaker_count=3)

    streaming_config = types.StreamingRecognitionConfig(config=config)
    
    # streaming_recognize returns a generator.
    responses = client.streaming_recognize(streaming_config, requests)
    
    for response in responses:
        for result in response.results:
            alternatives = result.alternatives
            for alternative in alternatives:
                print(u'Transcript: {}'.format(alternative.transcript))
                transcripts.append(alternative.transcript)    # punctuation 포함된 문장을 사용하기 위해 저장
                for words in alternative.words:
                    word = words.word
                    start_time = round(words.start_time.seconds + words.start_time.nanos * 1e-9, 3)
                    end_time = round(words.end_time.seconds + words.end_time.nanos * 1e-9, 3)
                    speaker_tag = words.speaker_tag
                    words_with_tag.append([word, start_time, end_time, speaker_tag])    # [word, start_time, end_time, speaker_tag]
        print()
    return words_with_tag, transcripts

# %%
def write_wave_frames(frames):
        wave_stream = wave.open(WAVE_OUTPUT_FILENAME, 'wb')
        wave_stream.setnchannels(CHANNELS)
        wave_stream.setsampwidth(FORMAT)
        wave_stream.setframerate(RATE)
        wave_stream.writeframes(b''.join(frames))
        wave_stream.close()

# %%
# instantiate PyAudio
audio = pyaudio.PyAudio()

# %%
# open wave file
FILE_NAME = "19m_20181220_deominju_16000"
wf = wave.open("audio_file/"+ FILE_NAME + ".wav", 'rb')

# %%
# initialize variables
CHUNK = 1024   # 1024 bytes of data read from the buffer
FRAME_SIZE = CHUNK * 4
WAVE_OUTPUT_FILENAME = "wave_output.wav"    # temperary wave file for streaming 
FORMAT=audio.get_sample_size(wf.getsampwidth())
CHANNELS=wf.getnchannels()
RATE=wf.getframerate()
words_with_tags = []
transcripts_arr = []
frames = []
f_count = 0

# %%
# read data (first frames)
data = wf.readframes(CHUNK)

# transcribe stream  : wave file을 10M 이하로 잘라서, google STT API에 stream 방식으로 요청
while len(data) > 0:
    frames.append(data)
    f_count += 1
    if f_count == FRAME_SIZE:
        # write frames to wave file for frames
        write_wave_frames(frames)
        
        # transcribe by streaming
        words_with_tag, transcripts = transcribe_streaming(WAVE_OUTPUT_FILENAME)    # frames를 직접 전달 시 google에서 grpc.RpcError 발생하면 cancel 됨 
        words_with_tags.append(words_with_tag)
        transcripts_arr.append(transcripts)
        
        # frame initialize
        frames = []
        f_count = 0
    
    # read data (continue)
    data = wf.readframes(CHUNK)

# transcribe for last frames
write_wave_frames(frames)

# last frames
words_with_tag, transcripts = transcribe_streaming(WAVE_OUTPUT_FILENAME)
words_with_tags.append(words_with_tag)
transcripts_arr.append(transcripts)
# Out:
# Transcript: 네 반갑습니다 제 115차 정책조정회의를 원내대표에 모두 바로 시작하겠습니다. 11 12 월 임시 이렇게 분위기가 아 이제 일주일 앞으로 다가왔습니다. 여야가 민생법안 처리를 위해 논의 속도를 더 내야겠습니다. 꼭 처리해야 할 과제는 6300번 산업안전보건법입니다. 6003번 오늘의 연애 법안소위에서 눈이 될 예정입니다. 오늘 합의가 이루어지지 않을 경우 27번의 처리가 사실상 어렵습니다. 자유한국당도 아이들이 하는 마음이 조금이라도 있다면 6003번 노니 접속 구매합니다. 지난번 정기국회 때처럼 법원 처리를.
#
# Transcript: 연 시키려는 무슨 국민이 용납하지 않을 것입니다. 우리 다음은 오늘 처리될 수 있도록 최선을 다해서 열린 자세로 소방서에 임하겠습니다. 그러나 끝내 자유한국당이 반대한다면 패스트트랙을 통해 처리하는 방안을 추진 하겠습니다. 위험의 외주화를 막을 산업안전보건법 또 반드시 처리하겠습니다. 더 이상 내몰리지 않기 위해서 필요한 법안입니다. 다행히 어제 황영희 고용노동청 위해서 27일 본회의에서 산업안전보건법을 처리하기 여야간 의견이 모아졌다습니다. 앞으로 돈이 과정에서 차질 없이 처리될 수 있도록 기도합니다.
#
# Transcript: 협상을 총괄하는 비건 미국 특별대표가 어제 방황하면서 주목할만한 메세지를 잡혀 있습니다. 인도적 차원에서 대북지원을 확실히 보장하고 미국인의 북한 여행 금지조치를 재검토하겠다고 밝혔다입니다. 남궁민 사이를 갈라놓을 어떤지 난 70년에 적대감을 뛰어넘을 수 있도록 북한과 확장하겠다는 운동했습니다. 그동안은 엄격한 대북제재 방침을 고수했던 미국이 유화책을 제시한 것입니다. 미국 정부가 인도적 차원에서 대북지원을 북미대화를 다시 진전 시키겠다는 강한 의지를 밝힌 것으로 해석된다. 북한이 어떤 반응을 보이는 양에 따라 행동할 교착상태를 보이던 대화가 재개 될 가능성도 충분히 있어 보입니다. 오늘과 내일 추석 대표회의 한미워킹그룹 2차 회의를 통해 한미 양국이 국민.
#
# Transcript: 새로운 돌파구를 마지막에 바랍니다. 미국식이 인도적 지원에 체제를 식사하면서 남북 교류 해도 탄력이 붙을 것으로 예상됩니다. 26일 열리는 남북 철도 착공시기 남북교류를 확대하고 북미대화 진전을 가져오는 계기가 되기를 바랍니다. 미국 중앙은행이 오늘 새벽 기준 금리를 또 인상했습니다. 월드 엄마는 벌써네 번째 기준 금리 인상입니다. 미국과 우리나라의 기준 금리격차 넣어서 벌어졌습니다. 미국 금리 인상은 우리 경제의 여러 측면에서 영향을 미치게 됩니다. 물론 당장은 우리 경제에 큰 영향은 없을 것이란 전망이 우세하다. 그러나 외국인자금 유출과 이로 인해 금융시장이 불안해질 가능성을 배제할 수 없.
#
# Transcript: 정부는 미국 금리인상이 우리 경제에 미치는 영향을 a 주셔야 합니다. 외국인 자금 흐름과 증시 등 유명 시장 상황을 면밀히 점검하고 이리 대응책을 마련해 주기 바랍니다. 1,500 도를 넘어선 가계부채도 철저하게 관리해야 합니다. 최근 부동산 가격이 안.
#
# Transcript: 되면서 가계부채증가 속도는 둔화되는 추세입니다. 그러나 앞으로 대출 금리가 더 오르는 상황에 대비해 합니다. 금리가 오르면 서민 취약계층을 위한 상환부담이 가중될 수밖에 없습니다. 정부는 금융권대출 기재를 다시 한번 점검해 주고 지하 2층에 부담이 걱정하지 않게 꼼꼼히 살펴 보시기 바랍니다. 택시업계가 지난 당대표 간담회에서 제한된 사회적대타협기구 참여를 약속했습니다. 그리고 오늘 예정된 대규모집회도 평화적으로 진행하겠다고 약속했습니다. 이런 일을 이끌어내기까지 우리당에 전현희 의원께서 많은 노력을 했습니다. 사실 쉽지 않은 그런 하겠습니다 많은.
#
# Transcript: 이 문제를 우리가 머리를 맞대고 대화와 타협을 통해서 풀 수 있는 중요한 초대를 만들었다고 생각합니다. 앞으로 택시 카풀, 어깨 함께 참여하는 사회적대화 지구에서 서로 상생하고 혁신성장을 위한 그런 사회적대타협 만들어질 수 있도록 최선을 다하겠습니다. 다음은 김태년 정책위의장은 알겠습니다. 조금 전 당장 관련 협의를 통해서 자영업 혁신과 성장을 견인할 종합대책을 마련했습니다. 문재인 정부 출범 이후 가장 적극적으로.
#
# Transcript: 책을 말이나 문화 중에 하나가 바로 소상공인자영업자 대책입니다. 그동안 종합대책을 막내 차례 발표를 했었는데요. 일자리, 안정자금, 사회보험료 등의 직접지원, 상가임대차 및 공정거래에 분야 제도개선 이런 정책들을 한 팩 46개 146개의 과제가 현재 추진되고 있고, 여기에 인제 오늘 종합대책이 발표가 되고 최근에 카드수수료 종합개편방안 발표를 대책 둘러 자영업자들의 경영난을 회수할 시급한 과제들은 어느정도 가닥이 잡혔다고 생각을 합니다. 이제는 자야 혁신과 성장이 가능한 생태계를 구축하는데 정책역량을 집중할 계획입니다. 또한 이번에 소상공인 자영업 업계와 논의해서.
#
# Transcript: 대책을 말이나 한 것처럼 앞으로도 현장과 긴밀하게 소통하면서 정책을 수립하고 집행할 것입니다. 영업 성장 혁신 종합대책에 자세한 내용은 지금 중기 중기 부와 관계부처에서 지금 발표를 하고 있을 텐데요. 주요 내용만 말씀 드리면 첫째로 구도심, 상권, 경기 소상공인, 복합지원센터 설치 등을 통해서 자영업에 송장 영향을 제거하는 것입니다. 두 번째로 제로페이 서비스 강화, 지역사랑상품권 및 온누리상품권 발행 확대 등을 통해서 자영업자에 매출을 실제로 늘리고 비용 부담 안 하는게 세 번째로 창업지원교육 제기를 아우르는 통합 지원 체계를 구축하는 것이네 번째로 가맹본부.
#
# Transcript: 가맹점주가 4 2 0 0 4 프랜차이즈 육성 등을 통해서 골목상권을 지키고 상생협력 문화를 문화를 확산해 나가는 것이 다섯 번째로 자영업자에 대한 사회적 안전망을 확대해 나가는 것이다. 혁신과.
#
# Transcript: 통장은 함께 잘 사는 혁신적포용국가로 나와 가지고 위한 핵심 과제 중에 하나입니다. 저희 더불어민주당은 오늘 발표한 대책이 차질 없이 집행되도록 만전을 기하겠습니다. 집행을 위한 범부처 간 또 당정 감 협업체계를 잘 구축하고 무엇보다도 현장에서 실질적으로 성과가 날 때까지 끈질기게 그렇게 점검하고 실행하겠다는 말씀드리고이를 위해서 과제들은 야당과 김미라 기흥역에서 조속히 입법절차를 마무리 짓겠습니다. 강릉펜션사고에 대해서 말씀 드리겠습니다. 먼저 안타까운 사고로 미생 뱀 학생들의 명복을 빌고 빌게 깊은 위로의 말씀을 드립니다. 현재 병원에 입원 중인 학생들이 빨리 와.
#
# Transcript: 사랑하는 가족들 곁으로 돌아가기를 기원합니다. 이번 사고의 잠정적인 원인은 보일러와 100개 연결 부위 문제로 인한 일산화탄소 노출입니다. 학생들이 숙박했던 펜션에 가스누출경보기가 설치 설치 되어 있지 않아 키웠습니다. 펜션은 농어촌민박업으로 분류되어서 가스누출경보기 설치의무가 없고 남방 안전점검항목에서 빠져 있기 때문입니다. 펜션 민박 시설의 안전관리실태를 점검하고 제도개선방안 마련이 시급하다고 판단됩니다. 그리고 민박 시설에 대한 안전 대책을 마련하는 것이 그치지 않고 이번 기회에 다중이용시설, 교통시설, 산업 현장 국민이 생활하고 일하는.
#
# Transcript: 시설과 공간에 대해서 안전관리실태 전반을 점검하고 개선 방안을 마련하는 것이 시급한 과제입니다. 최근 발생한 사고들의 거울 삼아서 안전에 사각지대에 놓인 각종 위험요소들을 면밀하게 살펴보고 종합적인 대책을 수입 하겠습니다. 정부와 긴밀한 협의를 통해서 안전과 관련된 정책들을 다시 한번 재정비하고 법개정이 필요한 사항은 조속한 시일 내에 마무리 짓겠습니다. 그리고 올해 초에 발표한 바 있는 국민생명지키기 3대 프로젝트 진행 상황 상황. 다시 한번 몇 미리 점검하도록 하겠습니다. 무엇보다도 정부의 대책이 사후약방문 되지 않도록 선제적으로 서치에서 사고를 예방해야 하겠습니다.
#
# Transcript: 당과 정부는 국민안전의 최우선의 가치를 들고 안전한 대한민국을 만들기에 최선을 다 하겠습니다. 오늘 축구 대표 바람이 됐습니다. 청와대 검찰로 b62 있어서 부피식 특별감찰반원 한마디에 야당이 출석하며 국기문란 진상조사단을 뿌린다는 뚱 행위를 하고 있습니다. 야당에게 축구 합니다. 기록으로 검찰이 복귀한 특별 감찰 받은 한마디에 정치공세를 하는 행위를 즉각 중단해야 할 것입니다. 청와대에 파견나온 특별감찰반원 김태우 수사관이 비위사실이 있어서 소속 중으로 다시 돌려 보내 주고 거기에 징계를 요청한.
#
# Transcript: 사랑입니다이 김태우 오감찰바 너는 이미 나왔던 기사들을 재탕하면서 촛불 하고 올리고 2017년 7월에 올렸던 내용 때문에 자신이 정치적으로 내비쳤다는 얼토당토않은 주장을 하고 있습니다이 김태우 수사관은 관계자 하고 자기 뒤를 밀어주는업자인지는 모르겠으나 관계 청와대 근무 시간에 골프를 쳤습니다. 업자가격.
#
# Transcript: 수원 되는 날 경찰청을 직접 방문해서 수사 내용들을 확인했습니다. 그리고 이강철 대상들과 주고 받은 문자 등이 있었고 이런 내용들을 밝혀진 내용입니다. 또다시 김태우에 대한 의혹들이 나오고 있습니다. 유착의 시민은 건설업자에게 명절 때마다 대통령님을 선물을 있다는 겁니다. 김태우 특별감찰반원 2kg가 넘긴 최고로 사입을 추구했다는 역으로 수사를 받고 있기도 합니다. 일부 언론은 민간 사철에 청와대가 저장한 것 아니냐, 이런 이야기하는데 민간인 사찰이라고 하는 것은 어떤 것인지 여러분께 오늘이 표를 제공해 드리도록 하겠습니다. 사찰들이 어떤 것이 맞는지이 내용에 정확히 나와 있습니다. 다시 한번 말씀 드리면 4대강 반대세력을 방해하고 기업홍보.
#
# Transcript: 차단하고 환경단체 핵심인물 24명을 감찰하고 세무조사를 압박하고 우리가 KB 한마음 김종익 대표는 수시로 사채를 받아서 자살시도를 여러 번 했던 기억도 있습니다. 그리고 기무사가 세월호 유가족, 실종자 가족 단원구 학생들을 불법사찰 했던 내용들. 이런 내용이 바로 과거 박근혜 정부에서 최순실 비선실세 국기문란 하면서 미뤄졌던 민간인 사찰입니다. 민간인 사찰이나 어떤 것인지 다시 한번 정확히 여러분이 파악하고 그리고 또 기사에 올려 주실 것을 당부드리며 써 언론은 자신들이 비 때문에 우리도 없이 할지 모른다라고 하는 착각은 그만둘 것을 촉구합니다 이상입니다.
#
# Transcript: 자비로 지도로 사서 대통령 선물을 업체에게 전달할 때는 마치 자기 돈으로 사서 마치 대통령께서 선물하신 것처럼 이렇게 위장하는 쓸수도 보였다라고 하는 것을 말씀 드리겠습니다. 정말 위원장에네 어제 오후 늦게 택시 4단체장 들겠어. 매우 어려운 결정을 내렸습니다. 택시 사단 채널, 택시, 자매가 플레이할 등을 해결하기 위해서 사회적대타협기구 참여하고 또 대화와 타협으로이 문제를 해결 하겠다. 나는 제안을 해오셨습니다. 그리고 오늘.
#
# Transcript: 있는 10만명 규모의 여의도집회도 평화적으로 진행하기로 하였습니다. 택시업계에 오늘 집회 되시면 그동안 많은 우려가 있어 채우기 기사님의 분신이 있었고, 택시업계는 생존권 투쟁으로 이번 집회를 교정시험만큼 극단적인 상황이 벌어질 우려가 있습니다. 정치권에서는 집회를 취소하거나 적어도 최소한 평화적 집회가 되어야 한다라는 고민이 깊어집니다. 극한대립 상황에서도 대화에 끈을 놓지 않은 택시 이쪽에 인내심에 깊은 감사드립니다. 그리고 이러한 결단을 내려주신 택시업계에 커플티 fun 진심으로 결단을 높이 평가 합니다. 오늘고 채우기 택시기사님의 영결식이 역시 예정되어 있습니다. 다시 한번!
#
# Transcript: 고인의 명복을 빌고 유가족들에게 깊은 위로를 드립니다. 다시는 이런 희생자가 발생하지 않도록 더불어민주당도 택시 산업 발전을 위해서 최선을 다하겠습니다. 감사합니다 가는 길.
#
# Transcript: 결정 생각합니다. 국민께서 관심을 가지고 지켜봐 주고 계시는 산업안전보건법 개정 않은 그러한 내용을 담고 있습니다. 우리가 제도를 통해서 모든 산업체를 모든 산업재를 통한 사망사고를 없앨수는 없겠습니다만, 제도를 통해서 최소화할 수 있습니다. 그 최소화하기 위한 정부 나 이뻐 보이는 거에 대해서 경제계는 이제 제발 응답해 주시기를 바랍니다이 법이 통과되기 되지 않기를 바라면서 입법 저지 노력하는 그 열정만큼 실제로 현장에서 산업재해를 줄이기 위해서 작업 죄로 인한 사고를 줄이기 위해서 사용자들이 무엇을 해야 하는지에 대해서 한 번 더 고민해 주시는 그런 시간을 가져 주시기를 바랍니다. 21일 공청회 그리고.
#
# Transcript: 법안소위 최대한 노력을 해서 24일까지는 전체 1일까지 마치고 1위를 통과시킨 다음에 27일 보내기에는 상정이 될 수 있도록 최대한 노력을 할 것입니다. 이렇게 입고가 누르고 하는 것에 대해서 경영계는 다시 한번 말씀 드립니다. 응답해 주시기를 바라겠습니다네 이상으로 제 115차 정책조정회의 동계 일 모두 마치도록 하겠습니다. 여러분들의!

# %%
# close PyAudio
audio.terminate()

# %%
corpus = ""
for transcripts in transcripts_arr:
    for transcript in transcripts:
        corpus += transcript + " "
# print(corpus)

# %%
sentence = sent_tokenize(corpus)    # 문장단위 분리
sentence
# Out:
# ['네 반갑습니다 제 115차 정책조정회의를 원내대표에 모두 바로 시작하겠습니다.',
#  '11 12 월 임시 이렇게 분위기가 아 이제 일주일 앞으로 다가왔습니다.',
#  '여야가 민생법안 처리를 위해 논의 속도를 더 내야겠습니다.',
#  '꼭 처리해야 할 과제는 6300번 산업안전보건법입니다.',
#  '6003번 오늘의 연애 법안소위에서 눈이 될 예정입니다.',
#  '오늘 합의가 이루어지지 않을 경우 27번의 처리가 사실상 어렵습니다.',
#  '자유한국당도 아이들이 하는 마음이 조금이라도 있다면 6003번 노니 접속 구매합니다.',
#  '지난번 정기국회 때처럼 법원 처리를.',
#  '연 시키려는 무슨 국민이 용납하지 않을 것입니다.',
#  '우리 다음은 오늘 처리될 수 있도록 최선을 다해서 열린 자세로 소방서에 임하겠습니다.',
#  '그러나 끝내 자유한국당이 반대한다면 패스트트랙을 통해 처리하는 방안을 추진 하겠습니다.',
#  '위험의 외주화를 막을 산업안전보건법 또 반드시 처리하겠습니다.',
#  '더 이상 내몰리지 않기 위해서 필요한 법안입니다.',
#  '다행히 어제 황영희 고용노동청 위해서 27일 본회의에서 산업안전보건법을 처리하기 여야간 의견이 모아졌다습니다.',
#  '앞으로 돈이 과정에서 차질 없이 처리될 수 있도록 기도합니다.',
#  '협상을 총괄하는 비건 미국 특별대표가 어제 방황하면서 주목할만한 메세지를 잡혀 있습니다.',
#  '인도적 차원에서 대북지원을 확실히 보장하고 미국인의 북한 여행 금지조치를 재검토하겠다고 밝혔다입니다.',
#  '남궁민 사이를 갈라놓을 어떤지 난 70년에 적대감을 뛰어넘을 수 있도록 북한과 확장하겠다는 운동했습니다.',
#  '그동안은 엄격한 대북제재 방침을 고수했던 미국이 유화책을 제시한 것입니다.',
#  '미국 정부가 인도적 차원에서 대북지원을 북미대화를 다시 진전 시키겠다는 강한 의지를 밝힌 것으로 해석된다.',
#  '북한이 어떤 반응을 보이는 양에 따라 행동할 교착상태를 보이던 대화가 재개 될 가능성도 충분히 있어 보입니다.',
#  '오늘과 내일 추석 대표회의 한미워킹그룹 2차 회의를 통해 한미 양국이 국민.',
#  '새로운 돌파구를 마지막에 바랍니다.',
#  '미국식이 인도적 지원에 체제를 식사하면서 남북 교류 해도 탄력이 붙을 것으로 예상됩니다.',
#  '26일 열리는 남북 철도 착공시기 남북교류를 확대하고 북미대화 진전을 가져오는 계기가 되기를 바랍니다.',
#  '미국 중앙은행이 오늘 새벽 기준 금리를 또 인상했습니다.',
#  '월드 엄마는 벌써네 번째 기준 금리 인상입니다.',
#  '미국과 우리나라의 기준 금리격차 넣어서 벌어졌습니다.',
#  '미국 금리 인상은 우리 경제의 여러 측면에서 영향을 미치게 됩니다.',
#  '물론 당장은 우리 경제에 큰 영향은 없을 것이란 전망이 우세하다.',
#  '그러나 외국인자금 유출과 이로 인해 금융시장이 불안해질 가능성을 배제할 수 없.',
#  '정부는 미국 금리인상이 우리 경제에 미치는 영향을 a 주셔야 합니다.',
#  '외국인 자금 흐름과 증시 등 유명 시장 상황을 면밀히 점검하고 이리 대응책을 마련해 주기 바랍니다.',
#  '1,500 도를 넘어선 가계부채도 철저하게 관리해야 합니다.',
#  '최근 부동산 가격이 안.',
#  '되면서 가계부채증가 속도는 둔화되는 추세입니다.',
#  '그러나 앞으로 대출 금리가 더 오르는 상황에 대비해 합니다.',
#  '금리가 오르면 서민 취약계층을 위한 상환부담이 가중될 수밖에 없습니다.',
#  '정부는 금융권대출 기재를 다시 한번 점검해 주고 지하 2층에 부담이 걱정하지 않게 꼼꼼히 살펴 보시기 바랍니다.',
#  '택시업계가 지난 당대표 간담회에서 제한된 사회적대타협기구 참여를 약속했습니다.',
#  '그리고 오늘 예정된 대규모집회도 평화적으로 진행하겠다고 약속했습니다.',
#  '이런 일을 이끌어내기까지 우리당에 전현희 의원께서 많은 노력을 했습니다.',
#  '사실 쉽지 않은 그런 하겠습니다 많은.',
#  '이 문제를 우리가 머리를 맞대고 대화와 타협을 통해서 풀 수 있는 중요한 초대를 만들었다고 생각합니다.',
#  '앞으로 택시 카풀, 어깨 함께 참여하는 사회적대화 지구에서 서로 상생하고 혁신성장을 위한 그런 사회적대타협 만들어질 수 있도록 최선을 다하겠습니다.',
#  '다음은 김태년 정책위의장은 알겠습니다.',
#  '조금 전 당장 관련 협의를 통해서 자영업 혁신과 성장을 견인할 종합대책을 마련했습니다.',
#  '문재인 정부 출범 이후 가장 적극적으로.',
#  '책을 말이나 문화 중에 하나가 바로 소상공인자영업자 대책입니다.',
#  '그동안 종합대책을 막내 차례 발표를 했었는데요.',
#  '일자리, 안정자금, 사회보험료 등의 직접지원, 상가임대차 및 공정거래에 분야 제도개선 이런 정책들을 한 팩 46개 146개의 과제가 현재 추진되고 있고, 여기에 인제 오늘 종합대책이 발표가 되고 최근에 카드수수료 종합개편방안 발표를 대책 둘러 자영업자들의 경영난을 회수할 시급한 과제들은 어느정도 가닥이 잡혔다고 생각을 합니다.',
#  '이제는 자야 혁신과 성장이 가능한 생태계를 구축하는데 정책역량을 집중할 계획입니다.',
#  '또한 이번에 소상공인 자영업 업계와 논의해서.',
#  '대책을 말이나 한 것처럼 앞으로도 현장과 긴밀하게 소통하면서 정책을 수립하고 집행할 것입니다.',
#  '영업 성장 혁신 종합대책에 자세한 내용은 지금 중기 중기 부와 관계부처에서 지금 발표를 하고 있을 텐데요.',
#  '주요 내용만 말씀 드리면 첫째로 구도심, 상권, 경기 소상공인, 복합지원센터 설치 등을 통해서 자영업에 송장 영향을 제거하는 것입니다.',
#  '두 번째로 제로페이 서비스 강화, 지역사랑상품권 및 온누리상품권 발행 확대 등을 통해서 자영업자에 매출을 실제로 늘리고 비용 부담 안 하는게 세 번째로 창업지원교육 제기를 아우르는 통합 지원 체계를 구축하는 것이네 번째로 가맹본부.',
#  '가맹점주가 4 2 0 0 4 프랜차이즈 육성 등을 통해서 골목상권을 지키고 상생협력 문화를 문화를 확산해 나가는 것이 다섯 번째로 자영업자에 대한 사회적 안전망을 확대해 나가는 것이다.',
#  '혁신과.',
#  '통장은 함께 잘 사는 혁신적포용국가로 나와 가지고 위한 핵심 과제 중에 하나입니다.',
#  '저희 더불어민주당은 오늘 발표한 대책이 차질 없이 집행되도록 만전을 기하겠습니다.',
#  '집행을 위한 범부처 간 또 당정 감 협업체계를 잘 구축하고 무엇보다도 현장에서 실질적으로 성과가 날 때까지 끈질기게 그렇게 점검하고 실행하겠다는 말씀드리고이를 위해서 과제들은 야당과 김미라 기흥역에서 조속히 입법절차를 마무리 짓겠습니다.',
#  '강릉펜션사고에 대해서 말씀 드리겠습니다.',
#  '먼저 안타까운 사고로 미생 뱀 학생들의 명복을 빌고 빌게 깊은 위로의 말씀을 드립니다.',
#  '현재 병원에 입원 중인 학생들이 빨리 와.',
#  '사랑하는 가족들 곁으로 돌아가기를 기원합니다.',
#  '이번 사고의 잠정적인 원인은 보일러와 100개 연결 부위 문제로 인한 일산화탄소 노출입니다.',
#  '학생들이 숙박했던 펜션에 가스누출경보기가 설치 설치 되어 있지 않아 키웠습니다.',
#  '펜션은 농어촌민박업으로 분류되어서 가스누출경보기 설치의무가 없고 남방 안전점검항목에서 빠져 있기 때문입니다.',
#  '펜션 민박 시설의 안전관리실태를 점검하고 제도개선방안 마련이 시급하다고 판단됩니다.',
#  '그리고 민박 시설에 대한 안전 대책을 마련하는 것이 그치지 않고 이번 기회에 다중이용시설, 교통시설, 산업 현장 국민이 생활하고 일하는.',
#  '시설과 공간에 대해서 안전관리실태 전반을 점검하고 개선 방안을 마련하는 것이 시급한 과제입니다.',
#  '최근 발생한 사고들의 거울 삼아서 안전에 사각지대에 놓인 각종 위험요소들을 면밀하게 살펴보고 종합적인 대책을 수입 하겠습니다.',
#  '정부와 긴밀한 협의를 통해서 안전과 관련된 정책들을 다시 한번 재정비하고 법개정이 필요한 사항은 조속한 시일 내에 마무리 짓겠습니다.',
#  '그리고 올해 초에 발표한 바 있는 국민생명지키기 3대 프로젝트 진행 상황 상황.',
#  '다시 한번 몇 미리 점검하도록 하겠습니다.',
#  '무엇보다도 정부의 대책이 사후약방문 되지 않도록 선제적으로 서치에서 사고를 예방해야 하겠습니다.',
#  '당과 정부는 국민안전의 최우선의 가치를 들고 안전한 대한민국을 만들기에 최선을 다 하겠습니다.',
#  '오늘 축구 대표 바람이 됐습니다.',
#  '청와대 검찰로 b62 있어서 부피식 특별감찰반원 한마디에 야당이 출석하며 국기문란 진상조사단을 뿌린다는 뚱 행위를 하고 있습니다.',
#  '야당에게 축구 합니다.',
#  '기록으로 검찰이 복귀한 특별 감찰 받은 한마디에 정치공세를 하는 행위를 즉각 중단해야 할 것입니다.',
#  '청와대에 파견나온 특별감찰반원 김태우 수사관이 비위사실이 있어서 소속 중으로 다시 돌려 보내 주고 거기에 징계를 요청한.',
#  '사랑입니다이 김태우 오감찰바 너는 이미 나왔던 기사들을 재탕하면서 촛불 하고 올리고 2017년 7월에 올렸던 내용 때문에 자신이 정치적으로 내비쳤다는 얼토당토않은 주장을 하고 있습니다이 김태우 수사관은 관계자 하고 자기 뒤를 밀어주는업자인지는 모르겠으나 관계 청와대 근무 시간에 골프를 쳤습니다.',
#  '업자가격.',
#  '수원 되는 날 경찰청을 직접 방문해서 수사 내용들을 확인했습니다.',
#  '그리고 이강철 대상들과 주고 받은 문자 등이 있었고 이런 내용들을 밝혀진 내용입니다.',
#  '또다시 김태우에 대한 의혹들이 나오고 있습니다.',
#  '유착의 시민은 건설업자에게 명절 때마다 대통령님을 선물을 있다는 겁니다.',
#  '김태우 특별감찰반원 2kg가 넘긴 최고로 사입을 추구했다는 역으로 수사를 받고 있기도 합니다.',
#  '일부 언론은 민간 사철에 청와대가 저장한 것 아니냐, 이런 이야기하는데 민간인 사찰이라고 하는 것은 어떤 것인지 여러분께 오늘이 표를 제공해 드리도록 하겠습니다.',
#  '사찰들이 어떤 것이 맞는지이 내용에 정확히 나와 있습니다.',
#  '다시 한번 말씀 드리면 4대강 반대세력을 방해하고 기업홍보.',
#  '차단하고 환경단체 핵심인물 24명을 감찰하고 세무조사를 압박하고 우리가 KB 한마음 김종익 대표는 수시로 사채를 받아서 자살시도를 여러 번 했던 기억도 있습니다.',
#  '그리고 기무사가 세월호 유가족, 실종자 가족 단원구 학생들을 불법사찰 했던 내용들.',
#  '이런 내용이 바로 과거 박근혜 정부에서 최순실 비선실세 국기문란 하면서 미뤄졌던 민간인 사찰입니다.',
#  '민간인 사찰이나 어떤 것인지 다시 한번 정확히 여러분이 파악하고 그리고 또 기사에 올려 주실 것을 당부드리며 써 언론은 자신들이 비 때문에 우리도 없이 할지 모른다라고 하는 착각은 그만둘 것을 촉구합니다 이상입니다.',
#  '자비로 지도로 사서 대통령 선물을 업체에게 전달할 때는 마치 자기 돈으로 사서 마치 대통령께서 선물하신 것처럼 이렇게 위장하는 쓸수도 보였다라고 하는 것을 말씀 드리겠습니다.',
#  '정말 위원장에네 어제 오후 늦게 택시 4단체장 들겠어.',
#  '매우 어려운 결정을 내렸습니다.',
#  '택시 사단 채널, 택시, 자매가 플레이할 등을 해결하기 위해서 사회적대타협기구 참여하고 또 대화와 타협으로이 문제를 해결 하겠다.',
#  '나는 제안을 해오셨습니다.',
#  '그리고 오늘.',
#  '있는 10만명 규모의 여의도집회도 평화적으로 진행하기로 하였습니다.',
#  '택시업계에 오늘 집회 되시면 그동안 많은 우려가 있어 채우기 기사님의 분신이 있었고, 택시업계는 생존권 투쟁으로 이번 집회를 교정시험만큼 극단적인 상황이 벌어질 우려가 있습니다.',
#  '정치권에서는 집회를 취소하거나 적어도 최소한 평화적 집회가 되어야 한다라는 고민이 깊어집니다.',
#  '극한대립 상황에서도 대화에 끈을 놓지 않은 택시 이쪽에 인내심에 깊은 감사드립니다.',
#  '그리고 이러한 결단을 내려주신 택시업계에 커플티 fun 진심으로 결단을 높이 평가 합니다.',
#  '오늘고 채우기 택시기사님의 영결식이 역시 예정되어 있습니다.',
#  '다시 한번!',
#  '고인의 명복을 빌고 유가족들에게 깊은 위로를 드립니다.',
#  '다시는 이런 희생자가 발생하지 않도록 더불어민주당도 택시 산업 발전을 위해서 최선을 다하겠습니다.',
#  '감사합니다 가는 길.',
#  '결정 생각합니다.',
#  '국민께서 관심을 가지고 지켜봐 주고 계시는 산업안전보건법 개정 않은 그러한 내용을 담고 있습니다.',
#  '우리가 제도를 통해서 모든 산업체를 모든 산업재를 통한 사망사고를 없앨수는 없겠습니다만, 제도를 통해서 최소화할 수 있습니다.',
#  '그 최소화하기 위한 정부 나 이뻐 보이는 거에 대해서 경제계는 이제 제발 응답해 주시기를 바랍니다이 법이 통과되기 되지 않기를 바라면서 입법 저지 노력하는 그 열정만큼 실제로 현장에서 산업재해를 줄이기 위해서 작업 죄로 인한 사고를 줄이기 위해서 사용자들이 무엇을 해야 하는지에 대해서 한 번 더 고민해 주시는 그런 시간을 가져 주시기를 바랍니다.',
#  '21일 공청회 그리고.',
#  '법안소위 최대한 노력을 해서 24일까지는 전체 1일까지 마치고 1위를 통과시킨 다음에 27일 보내기에는 상정이 될 수 있도록 최대한 노력을 할 것입니다.',
#  '이렇게 입고가 누르고 하는 것에 대해서 경영계는 다시 한번 말씀 드립니다.',
#  '응답해 주시기를 바라겠습니다네 이상으로 제 115차 정책조정회의 동계 일 모두 마치도록 하겠습니다.',
#  '여러분들의!']

# %%
# 스크립트 만 Text 파일로 저장 (with newline)
text_file = "text/" + FILE_NAME + ".txt"
with open(text_file, 'w', encoding='utf-8') as f:
    for sent in sentence:
        f.write(sent + "\n")

# %%
# print(words_with_tags)
words_array = [wt for wts in words_with_tags for wt in wts]
words_array
# Out:
# [['네', 0.4, 6.9, 1],
#  ['반갑습니다', 6.9, 7.2, 1],
#  ['제', 7.2, 7.8, 1],
#  ['115차', 7.8, 8.7, 1],
#  ['정책조정회의', 8.7, 9.5, 1],
#  ['를', 9.5, 9.9, 1],
#  ['원내대표에', 9.9, 11.0, 1],
#  ['모두', 11.0, 11.2, 1],
#  ['바로', 11.2, 11.5, 1],
#  ['시작하겠습니다', 11.5, 12.0, 1],
#  ['11', 12.0, 15.5, 1],
#  ['12', 15.5, 16.3, 1],
#  ['월', 16.3, 16.6, 1],
#  ['임시', 16.6, 17.1, 1],
#  ['이렇게', 17.1, 17.5, 1],
#  ['분위기가', 17.5, 18.2, 1],
#  ['아', 18.2, 18.9, 1],
#  ['이제', 18.9, 19.4, 1],
#  ['일주일', 19.4, 19.7, 1],
#  ['앞으로', 19.7, 20.2, 1],
#  ['다가왔습니다', 20.2, 20.6, 1],
#  ['여야가', 20.6, 22.6, 1],
#  ['민생법안', 22.6, 23.6, 1],
#  ['처리를', 23.6, 24.1, 1],
#  ['위해', 24.1, 24.3, 1],
#  ['논의', 24.3, 25.3, 1],
#  ['속도를', 25.3, 26.1, 1],
#  ['더', 26.1, 26.3, 1],
#  ['내야겠습니다', 26.3, 26.8, 1],
#  ['꼭', 26.8, 28.6, 1],
#  ['처리해야', 28.6, 29.3, 1],
#  ['할', 29.3, 29.6, 1],
#  ['과제는', 29.6, 30.5, 1],
#  ['6300번', 30.5, 31.9, 1],
#  ['산업안전보건법', 31.9, 33.6, 1],
#  ['입니다', 33.6, 34.0, 1],
#  ['6003번', 34.0, 36.0, 1],
#  ['오늘', 36.0, 36.3, 1],
#  ['의', 36.3, 36.8, 1],
#  ['연애', 36.8, 37.0, 1],
#  ['법안소위에서', 37.0, 38.1, 1],
#  ['눈이', 38.1, 38.8, 1],
#  ['될', 38.8, 39.1, 1],
#  ['예정입니다', 39.1, 39.8, 1],
#  ['오늘', 39.8, 40.7, 1],
#  ['합의가', 40.7, 41.3, 1],
#  ['이루어지지', 41.3, 41.9, 1],
#  ['않을', 41.9, 42.2, 1],
#  ['경우', 42.2, 42.6, 1],
#  ['27번의', 42.6, 44.2, 1],
#  ['처리가', 44.2, 44.9, 1],
#  ['사실상', 44.9, 45.5, 1],
#  ['어렵습니다', 45.5, 46.2, 1],
#  ['자유한국당', 46.2, 48.0, 1],
#  ['도', 48.0, 48.2, 1],
#  ['아이들이', 48.2, 49.1, 1],
#  ['하는', 49.1, 49.3, 1],
#  ['마음이', 49.3, 49.8, 1],
#  ['조금이라도', 49.8, 50.4, 1],
#  ['있다면', 50.4, 50.8, 1],
#  ['6003번', 50.8, 52.2, 1],
#  ['노니', 52.2, 52.5, 1],
#  ['접속', 52.5, 53.5, 1],
#  ['구매합니다', 53.5, 54.3, 1],
#  ['지난번', 54.3, 56.6, 1],
#  ['정기국회', 56.6, 57.2, 1],
#  ['때처럼', 57.2, 57.7, 1],
#  ['법원', 57.7, 59.6, 1],
#  ['처리를', 59.6, 60.2, 1],
#  ['네', 0.4, 6.9, 1],
#  ['반갑습니다', 6.9, 7.2, 1],
#  ['제', 7.2, 7.8, 1],
#  ['115차', 7.8, 8.7, 1],
#  ['정책조정회의', 8.7, 9.5, 1],
#  ['를', 9.5, 9.9, 1],
#  ['원내대표에', 9.9, 11.0, 1],
#  ['모두', 11.0, 11.2, 1],
#  ['바로', 11.2, 11.5, 1],
#  ['시작하겠습니다', 11.5, 12.0, 1],
#  ['11', 12.0, 15.5, 1],
#  ['12', 15.5, 16.3, 1],
#  ['월', 16.3, 16.6, 1],
#  ['임시', 16.6, 17.1, 1],
#  ['이렇게', 17.1, 17.5, 1],
#  ['분위기가', 17.5, 18.2, 1],
#  ['아', 18.2, 18.9, 1],
#  ['이제', 18.9, 19.4, 1],
#  ['일주일', 19.4, 19.7, 1],
#  ['앞으로', 19.7, 20.2, 1],
#  ['다가왔습니다', 20.2, 20.6, 1],
#  ['여야가', 20.6, 22.6, 1],
#  ['민생법안', 22.6, 23.6, 1],
#  ['처리를', 23.6, 24.1, 1],
#  ['위해', 24.1, 24.3, 1],
#  ['논의', 24.3, 25.3, 1],
#  ['속도를', 25.3, 26.1, 1],
#  ['더', 26.1, 26.3, 1],
#  ['내야겠습니다', 26.3, 26.8, 1],
#  ['꼭', 26.8, 28.6, 1],
#  ['처리해야', 28.6, 29.3, 1],
#  ['할', 29.3, 29.6, 1],
#  ['과제는', 29.6, 30.5, 1],
#  ['6300번', 30.5, 31.9, 1],
#  ['산업안전보건법', 31.9, 33.6, 1],
#  ['입니다', 33.6, 34.0, 1],
#  ['6003번', 34.0, 36.0, 1],
#  ['오늘', 36.0, 36.3, 1],
#  ['의', 36.3, 36.8, 1],
#  ['연애', 36.8, 37.0, 1],
#  ['법안소위에서', 37.0, 38.1, 1],
#  ['눈이', 38.1, 38.8, 1],
#  ['될', 38.8, 39.1, 1],
#  ['예정입니다', 39.1, 39.8, 1],
#  ['오늘', 39.8, 40.7, 1],
#  ['합의가', 40.7, 41.3, 1],
#  ['이루어지지', 41.3, 41.9, 1],
#  ['않을', 41.9, 42.2, 1],
#  ['경우', 42.2, 42.6, 1],
#  ['27번의', 42.6, 44.2, 1],
#  ['처리가', 44.2, 44.9, 1],
#  ['사실상', 44.9, 45.5, 1],
#  ['어렵습니다', 45.5, 46.2, 1],
#  ['자유한국당', 46.2, 48.0, 1],
#  ['도', 48.0, 48.2, 1],
#  ['아이들이', 48.2, 49.1, 1],
#  ['하는', 49.1, 49.3, 1],
#  ['마음이', 49.3, 49.8, 1],
#  ['조금이라도', 49.8, 50.4, 1],
#  ['있다면', 50.4, 50.8, 1],
#  ['6003번', 50.8, 52.2, 1],
#  ['노니', 52.2, 52.5, 1],
#  ['접속', 52.5, 53.5, 1],
#  ['구매합니다', 53.5, 54.3, 1],
#  ['지난번', 54.3, 56.6, 1],
#  ['정기국회', 56.6, 57.2, 1],
#  ['때처럼', 57.2, 57.7, 1],
#  ['법원', 57.7, 59.6, 1],
#  ['처리를', 59.6, 60.2, 1],
#  ['연', 60.4, 60.9, 1],
#  ['시키려는', 60.9, 61.8, 1],
#  ['무슨', 61.8, 62.5, 1],
#  ['국민이', 62.5, 63.7, 1],
#  ['용납하지', 63.7, 64.6, 1],
#  ['않을', 64.6, 64.9, 1],
#  ['것입니다', 64.9, 65.2, 1],
#  ['우리', 65.2, 66.9, 1],
#  ['다음은', 66.9, 67.3, 1],
#  ['오늘', 67.3, 68.0, 1],
#  ['처리될', 68.0, 69.3, 1],
#  ['수', 69.3, 69.4, 1],
#  ['있도록', 69.4, 69.5, 1],
#  ['최선을', 69.5, 70.7, 1],
#  ['다해서', 70.7, 70.9, 1],
#  ['열린', 70.9, 71.6, 1],
#  ['자세로', 71.6, 71.8, 1],
#  ['소방서에', 71.8, 73.5, 1],
#  ['임하겠습니다', 73.5, 74.0, 1],
#  ['그러나', 74.0, 76.6, 1],
#  ['끝내', 76.6, 77.4, 1],
#  ['자유한국당이', 77.4, 78.6, 1],
#  ['반대한다면', 78.6, 79.8, 1],
#  ['패스트트랙을', 79.8, 82.6, 1],
#  ['통해', 82.6, 83.7, 1],
#  ['처리하는', 83.7, 85.6, 1],
#  ['방안을', 85.6, 86.2, 1],
#  ['추진', 86.2, 87.6, 1],
#  ['하겠습니다', 87.6, 88.2, 1],
#  ['위험의', 88.2, 90.0, 1],
#  ['외주화', 90.0, 90.0, 1],
#  ['를', 90.0, 90.6, 1],
#  ['막을', 90.6, 91.1, 1],
#  ['산업안전보건법', 91.1, 93.0, 1],
#  ['또', 93.0, 93.2, 1],
#  ['반드시', 93.2, 93.7, 1],
#  ['처리하겠습니다', 93.7, 94.4, 1],
#  ['더', 94.4, 97.1, 1],
#  ['이상', 97.1, 97.4, 1],
#  ['내몰리지', 97.4, 99.0, 1],
#  ['않기', 99.0, 99.3, 1],
#  ['위해서', 99.3, 99.7, 1],
#  ['필요한', 99.7, 100.0, 1],
#  ['법안입니다', 100.0, 100.5, 1],
#  ['다행히', 100.5, 102.0, 1],
#  ['어제', 102.0, 102.5, 1],
#  ['황영희', 102.5, 103.0, 1],
#  ['고용노동청', 103.0, 103.9, 1],
#  ['위해서', 103.9, 104.3, 1],
#  ['27일', 104.3, 105.1, 1],
#  ['본회의에서', 105.1, 105.6, 1],
#  ['산업안전보건법을', 105.6, 107.7, 1],
#  ['처리하기', 107.7, 108.4, 1],
#  ['여야간', 108.4, 109.2, 1],
#  ['의견이', 109.2, 110.1, 1],
#  ['모아졌다', 110.1, 110.5, 1],
#  ['습니다', 110.5, 111.0, 1],
#  ['앞으로', 111.0, 111.9, 1],
#  ['돈', 111.9, 112.0, 1],
#  ['이', 112.0, 112.1, 1],
#  ['과정에서', 112.1, 112.8, 1],
#  ['차질', 112.8, 113.4, 1],
#  ['없이', 113.4, 113.7, 1],
#  ['처리될', 113.7, 115.4, 1],
#  ['수', 115.4, 115.4, 1],
#  ['있도록', 115.4, 115.6, 1],
#  ['기도합니다', 115.6, 117.4, 1],
#  ['네', 0.4, 6.9, 1],
#  ['반갑습니다', 6.9, 7.2, 1],
#  ['제', 7.2, 7.8, 1],
#  ['115차', 7.8, 8.7, 1],
#  ['정책조정회의', 8.7, 9.5, 1],
#  ['를', 9.5, 9.9, 1],
#  ['원내대표에', 9.9, 11.0, 1],
#  ['모두', 11.0, 11.2, 1],
#  ['바로', 11.2, 11.5, 1],
#  ['시작하겠습니다', 11.5, 12.0, 1],
#  ['11', 12.0, 15.5, 1],
#  ['12', 15.5, 16.3, 1],
#  ['월', 16.3, 16.6, 1],
#  ['임시', 16.6, 17.1, 1],
#  ['이렇게', 17.1, 17.5, 1],
#  ['분위기가', 17.5, 18.2, 1],
#  ['아', 18.2, 18.9, 1],
#  ['이제', 18.9, 19.4, 1],
#  ['일주일', 19.4, 19.7, 1],
#  ['앞으로', 19.7, 20.2, 1],
#  ['다가왔습니다', 20.2, 20.6, 1],
#  ['여야가', 20.6, 22.6, 1],
#  ['민생법안', 22.6, 23.6, 1],
#  ['처리를', 23.6, 24.1, 1],
#  ['위해', 24.1, 24.3, 1],
#  ['논의', 24.3, 25.3, 1],
#  ['속도를', 25.3, 26.1, 1],
#  ['더', 26.1, 26.3, 1],
#  ['내야겠습니다', 26.3, 26.8, 1],
#  ['꼭', 26.8, 28.6, 1],
#  ['처리해야', 28.6, 29.3, 1],
#  ['할', 29.3, 29.6, 1],
#  ['과제는', 29.6, 30.5, 1],
#  ['6300번', 30.5, 31.9, 1],
#  ['산업안전보건법', 31.9, 33.6, 1],
#  ['입니다', 33.6, 34.0, 1],
#  ['6003번', 34.0, 36.0, 1],
#  ['오늘', 36.0, 36.3, 1],
#  ['의', 36.3, 36.8, 1],
#  ['연애', 36.8, 37.0, 1],
#  ['법안소위에서', 37.0, 38.1, 1],
#  ['눈이', 38.1, 38.8, 1],
#  ['될', 38.8, 39.1, 1],
#  ['예정입니다', 39.1, 39.8, 1],
#  ['오늘', 39.8, 40.7, 1],
#  ['합의가', 40.7, 41.3, 1],
#  ['이루어지지', 41.3, 41.9, 1],
#  ['않을', 41.9, 42.2, 1],
#  ['경우', 42.2, 42.6, 1],
#  ['27번의', 42.6, 44.2, 1],
#  ['처리가', 44.2, 44.9, 1],
#  ['사실상', 44.9, 45.5, 1],
#  ['어렵습니다', 45.5, 46.2, 1],
#  ['자유한국당', 46.2, 48.0, 1],
#  ['도', 48.0, 48.2, 1],
#  ['아이들이', 48.2, 49.1, 1],
#  ['하는', 49.1, 49.3, 1],
#  ['마음이', 49.3, 49.8, 1],
#  ['조금이라도', 49.8, 50.4, 1],
#  ['있다면', 50.4, 50.8, 1],
#  ['6003번', 50.8, 52.2, 1],
#  ['노니', 52.2, 52.5, 1],
#  ['접속', 52.5, 53.5, 1],
#  ['구매합니다', 53.5, 54.3, 1],
#  ['지난번', 54.3, 56.6, 1],
#  ['정기국회', 56.6, 57.2, 1],
#  ['때처럼', 57.2, 57.7, 1],
#  ['법원', 57.7, 59.6, 1],
#  ['처리를', 59.6, 60.2, 1],
#  ['연', 60.4, 60.9, 1],
#  ['시키려는', 60.9, 61.8, 1],
#  ['무슨', 61.8, 62.5, 1],
#  ['국민이', 62.5, 63.7, 1],
#  ['용납하지', 63.7, 64.6, 1],
#  ['않을', 64.6, 64.9, 1],
#  ['것입니다', 64.9, 65.2, 1],
#  ['우리', 65.2, 66.9, 1],
#  ['다음은', 66.9, 67.3, 1],
#  ['오늘', 67.3, 68.0, 1],
#  ['처리될', 68.0, 69.3, 1],
#  ['수', 69.3, 69.4, 1],
#  ['있도록', 69.4, 69.5, 1],
#  ['최선을', 69.5, 70.7, 1],
#  ['다해서', 70.7, 70.9, 1],
#  ['열린', 70.9, 71.6, 1],
#  ['자세로', 71.6, 71.8, 1],
#  ['소방서에', 71.8, 73.5, 1],
#  ['임하겠습니다', 73.5, 74.0, 1],
#  ['그러나', 74.0, 76.6, 1],
#  ['끝내', 76.6, 77.4, 1],
#  ['자유한국당이', 77.4, 78.6, 1],
#  ['반대한다면', 78.6, 79.8, 1],
#  ['패스트트랙을', 79.8, 82.6, 1],
#  ['통해', 82.6, 83.7, 1],
#  ['처리하는', 83.7, 85.6, 1],
#  ['방안을', 85.6, 86.2, 1],
#  ['추진', 86.2, 87.6, 1],
#  ['하겠습니다', 87.6, 88.2, 1],
#  ['위험의', 88.2, 90.0, 1],
#  ['외주화', 90.0, 90.0, 1],
#  ['를', 90.0, 90.6, 1],
#  ['막을', 90.6, 91.1, 1],
#  ['산업안전보건법', 91.1, 93.0, 1],
#  ['또', 93.0, 93.2, 1],
#  ['반드시', 93.2, 93.7, 1],
#  ['처리하겠습니다', 93.7, 94.4, 1],
#  ['더', 94.4, 97.1, 1],
#  ['이상', 97.1, 97.4, 1],
#  ['내몰리지', 97.4, 99.0, 1],
#  ['않기', 99.0, 99.3, 1],
#  ['위해서', 99.3, 99.7, 1],
#  ['필요한', 99.7, 100.0, 1],
#  ['법안입니다', 100.0, 100.5, 1],
#  ['다행히', 100.5, 102.0, 1],
#  ['어제', 102.0, 102.5, 1],
#  ['황영희', 102.5, 103.0, 1],
#  ['고용노동청', 103.0, 103.9, 1],
#  ['위해서', 103.9, 104.3, 1],
#  ['27일', 104.3, 105.1, 1],
#  ['본회의에서', 105.1, 105.6, 1],
#  ['산업안전보건법을', 105.6, 107.7, 1],
#  ['처리하기', 107.7, 108.4, 1],
#  ['여야간', 108.4, 109.2, 1],
#  ['의견이', 109.2, 110.1, 1],
#  ['모아졌다', 110.1, 110.5, 1],
#  ['습니다', 110.5, 111.0, 1],
#  ['앞으로', 111.0, 111.9, 1],
#  ['돈', 111.9, 112.0, 1],
#  ['이', 112.0, 112.1, 1],
#  ['과정에서', 112.1, 112.8, 1],
#  ['차질', 112.8, 113.4, 1],
#  ['없이', 113.4, 113.7, 1],
#  ['처리될', 113.7, 115.4, 1],
#  ['수', 115.4, 115.4, 1],
#  ['있도록', 115.4, 115.6, 1],
#  ['기도합니다', 115.6, 117.4, 1],
#  ['협상을', 120.4, 121.3, 1],
#  ['총괄하는', 121.3, 121.7, 1],
#  ['비건', 121.7, 122.5, 1],
#  ['미국', 122.5, 122.9, 1],
#  ['특별대표가', 122.9, 123.7, 1],
#  ['어제', 123.7, 124.0, 1],
#  ['방황하면서', 124.0, 124.7, 1],
#  ['주목할만한', 124.7, 126.1, 1],
#  ['메세지를', 126.1, 126.8, 1],
#  ['잡혀', 126.8, 127.1, 1],
#  ['있습니다', 127.1, 127.3, 1],
#  ['인도적', 127.3, 128.6, 1],
#  ['차원에서', 128.6, 128.8, 1],
#  ['대북지원을', 128.8, 129.8, 1],
#  ['확실히', 129.8, 130.3, 1],
#  ['보장하고', 130.3, 130.8, 1],
#  ['미국인의', 130.8, 131.9, 1],
#  ['북한', 131.9, 132.6, 1],
#  ['여행', 132.6, 133.0, 1],
#  ['금지조치를', 133.0, 133.7, 1],
#  ['재검토하겠다고', 133.7, 134.9, 1],
#  ['밝혔다', 134.9, 135.1, 1],
#  ['입니다', 135.1, 135.7, 1],
#  ['남궁민', 135.7, 137.6, 1],
#  ['사이를', 137.6, 137.9, 1],
#  ['갈라놓을', 137.9, 138.4, 1],
#  ['어떤지', 138.4, 138.8, 1],
#  ['난', 138.8, 139.0, 1],
#  ['70년에', 139.0, 139.6, 1],
#  ['적대감을', 139.6, 140.4, 1],
#  ['뛰어넘을', 140.4, 141.2, 1],
#  ['수', 141.2, 141.3, 1],
#  ['있도록', 141.3, 141.7, 1],
#  ['북한과', 141.7, 143.0, 1],
#  ['확장하겠다는', 143.0, 143.8, 1],
#  ['운동했습니다', 143.8, 145.0, 1],
#  ['그동안은', 145.0, 146.5, 1],
#  ['엄격한', 146.5, 147.1, 1],
#  ['대북제재', 147.1, 147.7, 1],
#  ['방침을', 147.7, 148.3, 1],
#  ['고수했던', 148.3, 148.9, 1],
#  ['미국이', 148.9, 149.4, 1],
#  ['유화책을', 149.4, 151.0, 1],
#  ['제시한', 151.0, 151.4, 1],
#  ['것입니다', 151.4, 151.9, 1],
#  ['미국', 151.9, 153.1, 1],
#  ['정부가', 153.1, 153.5, 1],
#  ['인도적', 153.5, 154.6, 1],
#  ['차원에서', 154.6, 154.8, 1],
#  ['대북지원을', 154.8, 156.1, 1],
#  ['북미대화를', 156.1, 157.9, 1],
#  ['다시', 157.9, 158.5, 1],
#  ['진전', 158.5, 159.1, 1],
#  ['시키겠다는', 159.1, 159.8, 1],
#  ['강한', 159.8, 160.4, 1],
#  ['의지를', 160.4, 160.7, 1],
#  ['밝힌', 160.7, 161.5, 1],
#  ['것으로', 161.5, 162.0, 1],
#  ['해석된다', 162.0, 162.9, 1],
#  ['북한이', 162.9, 164.2, 1],
#  ['어떤', 164.2, 164.5, 1],
#  ['반응을', 164.5, 164.8, 1],
#  ['보이는', 164.8, 165.3, 1],
#  ['양에', 165.3, 165.5, 1],
#  ['따라', 165.5, 165.8, 1],
#  ['행동할', 165.8, 166.4, 1],
#  ['교착상태를', 166.4, 167.8, 1],
#  ['보이던', 167.8, 168.3, 1],
#  ['대화가', 168.3, 169.4, 1],
#  ['재개', 169.4, 170.2, 1],
#  ['될', 170.2, 170.3, 1],
#  ['가능성도', 170.3, 171.0, 1],
#  ['충분히', 171.0, 171.6, 1],
#  ['있어', 171.6, 171.9, 1],
#  ['보입니다', 171.9, 172.2, 1],
#  ['오늘과', 172.2, 173.7, 1],
#  ['내일', 173.7, 174.1, 1],
#  ['추석', 174.1, 174.9, 1],
#  ['대표회의', 174.9, 175.8, 1],
#  ['한미워킹그룹', 175.8, 177.3, 1],
#  ['2차', 177.3, 177.5, 1],
#  ['회의를', 177.5, 177.9, 1],
#  ['통해', 177.9, 178.2, 1],
#  ['한미', 178.2, 178.7, 1],
#  ['양국이', 178.7, 179.1, 1],
#  ['국민', 179.1, 179.9, 1],
#  ['네', 0.4, 6.9, 1],
#  ['반갑습니다', 6.9, 7.2, 1],
#  ['제', 7.2, 7.8, 1],
#  ['115차', 7.8, 8.7, 1],
#  ['정책조정회의', 8.7, 9.5, 1],
#  ['를', 9.5, 9.9, 1],
#  ['원내대표에', 9.9, 11.0, 1],
#  ['모두', 11.0, 11.2, 1],
#  ['바로', 11.2, 11.5, 1],
#  ['시작하겠습니다', 11.5, 12.0, 1],
#  ['11', 12.0, 15.5, 1],
#  ['12', 15.5, 16.3, 1],
#  ['월', 16.3, 16.6, 1],
#  ['임시', 16.6, 17.1, 1],
#  ['이렇게', 17.1, 17.5, 1],
#  ['분위기가', 17.5, 18.2, 1],
#  ['아', 18.2, 18.9, 1],
#  ['이제', 18.9, 19.4, 1],
#  ['일주일', 19.4, 19.7, 1],
#  ['앞으로', 19.7, 20.2, 1],
#  ['다가왔습니다', 20.2, 20.6, 1],
#  ['여야가', 20.6, 22.6, 1],
#  ['민생법안', 22.6, 23.6, 1],
#  ['처리를', 23.6, 24.1, 1],
#  ['위해', 24.1, 24.3, 1],
#  ['논의', 24.3, 25.3, 1],
#  ['속도를', 25.3, 26.1, 1],
#  ['더', 26.1, 26.3, 1],
#  ['내야겠습니다', 26.3, 26.8, 1],
#  ['꼭', 26.8, 28.6, 1],
#  ['처리해야', 28.6, 29.3, 1],
#  ['할', 29.3, 29.6, 1],
#  ['과제는', 29.6, 30.5, 1],
#  ['6300번', 30.5, 31.9, 1],
#  ['산업안전보건법', 31.9, 33.6, 1],
#  ['입니다', 33.6, 34.0, 1],
#  ['6003번', 34.0, 36.0, 1],
#  ['오늘', 36.0, 36.3, 1],
#  ['의', 36.3, 36.8, 1],
#  ['연애', 36.8, 37.0, 1],
#  ['법안소위에서', 37.0, 38.1, 1],
#  ['눈이', 38.1, 38.8, 1],
#  ['될', 38.8, 39.1, 1],
#  ['예정입니다', 39.1, 39.8, 1],
#  ['오늘', 39.8, 40.7, 1],
#  ['합의가', 40.7, 41.3, 1],
#  ['이루어지지', 41.3, 41.9, 1],
#  ['않을', 41.9, 42.2, 1],
#  ['경우', 42.2, 42.6, 1],
#  ['27번의', 42.6, 44.2, 1],
#  ['처리가', 44.2, 44.9, 1],
#  ['사실상', 44.9, 45.5, 1],
#  ['어렵습니다', 45.5, 46.2, 1],
#  ['자유한국당', 46.2, 48.0, 1],
#  ['도', 48.0, 48.2, 1],
#  ['아이들이', 48.2, 49.1, 1],
#  ['하는', 49.1, 49.3, 1],
#  ['마음이', 49.3, 49.8, 1],
#  ['조금이라도', 49.8, 50.4, 1],
#  ['있다면', 50.4, 50.8, 1],
#  ['6003번', 50.8, 52.2, 1],
#  ['노니', 52.2, 52.5, 1],
#  ['접속', 52.5, 53.5, 1],
#  ['구매합니다', 53.5, 54.3, 1],
#  ['지난번', 54.3, 56.6, 1],
#  ['정기국회', 56.6, 57.2, 1],
#  ['때처럼', 57.2, 57.7, 1],
#  ['법원', 57.7, 59.6, 1],
#  ['처리를', 59.6, 60.2, 1],
#  ['연', 60.4, 60.9, 1],
#  ['시키려는', 60.9, 61.8, 1],
#  ['무슨', 61.8, 62.5, 1],
#  ['국민이', 62.5, 63.7, 1],
#  ['용납하지', 63.7, 64.6, 1],
#  ['않을', 64.6, 64.9, 1],
#  ['것입니다', 64.9, 65.2, 1],
#  ['우리', 65.2, 66.9, 1],
#  ['다음은', 66.9, 67.3, 1],
#  ['오늘', 67.3, 68.0, 1],
#  ['처리될', 68.0, 69.3, 1],
#  ['수', 69.3, 69.4, 1],
#  ['있도록', 69.4, 69.5, 1],
#  ['최선을', 69.5, 70.7, 1],
#  ['다해서', 70.7, 70.9, 1],
#  ['열린', 70.9, 71.6, 1],
#  ['자세로', 71.6, 71.8, 1],
#  ['소방서에', 71.8, 73.5, 1],
#  ['임하겠습니다', 73.5, 74.0, 1],
#  ['그러나', 74.0, 76.6, 1],
#  ['끝내', 76.6, 77.4, 1],
#  ['자유한국당이', 77.4, 78.6, 1],
#  ['반대한다면', 78.6, 79.8, 1],
#  ['패스트트랙을', 79.8, 82.6, 1],
#  ['통해', 82.6, 83.7, 1],
#  ['처리하는', 83.7, 85.6, 1],
#  ['방안을', 85.6, 86.2, 1],
#  ['추진', 86.2, 87.6, 1],
#  ['하겠습니다', 87.6, 88.2, 1],
#  ['위험의', 88.2, 90.0, 1],
#  ['외주화', 90.0, 90.0, 1],
#  ['를', 90.0, 90.6, 1],
#  ['막을', 90.6, 91.1, 1],
#  ['산업안전보건법', 91.1, 93.0, 1],
#  ['또', 93.0, 93.2, 1],
#  ['반드시', 93.2, 93.7, 1],
#  ['처리하겠습니다', 93.7, 94.4, 1],
#  ['더', 94.4, 97.1, 1],
#  ['이상', 97.1, 97.4, 1],
#  ['내몰리지', 97.4, 99.0, 1],
#  ['않기', 99.0, 99.3, 1],
#  ['위해서', 99.3, 99.7, 1],
#  ['필요한', 99.7, 100.0, 1],
#  ['법안입니다', 100.0, 100.5, 1],
#  ['다행히', 100.5, 102.0, 1],
#  ['어제', 102.0, 102.5, 1],
#  ['황영희', 102.5, 103.0, 1],
#  ['고용노동청', 103.0, 103.9, 1],
#  ['위해서', 103.9, 104.3, 1],
#  ['27일', 104.3, 105.1, 1],
#  ['본회의에서', 105.1, 105.6, 1],
#  ['산업안전보건법을', 105.6, 107.7, 1],
#  ['처리하기', 107.7, 108.4, 1],
#  ['여야간', 108.4, 109.2, 1],
#  ['의견이', 109.2, 110.1, 1],
#  ['모아졌다', 110.1, 110.5, 1],
#  ['습니다', 110.5, 111.0, 1],
#  ['앞으로', 111.0, 111.9, 1],
#  ['돈', 111.9, 112.0, 1],
#  ['이', 112.0, 112.1, 1],
#  ['과정에서', 112.1, 112.8, 1],
#  ['차질', 112.8, 113.4, 1],
#  ['없이', 113.4, 113.7, 1],
#  ['처리될', 113.7, 115.4, 1],
#  ['수', 115.4, 115.4, 1],
#  ['있도록', 115.4, 115.6, 1],
#  ['기도합니다', 115.6, 117.4, 1],
#  ['협상을', 120.4, 121.3, 1],
#  ['총괄하는', 121.3, 121.7, 1],
#  ['비건', 121.7, 122.5, 1],
#  ['미국', 122.5, 122.9, 1],
#  ['특별대표가', 122.9, 123.7, 1],
#  ['어제', 123.7, 124.0, 1],
#  ['방황하면서', 124.0, 124.7, 1],
#  ['주목할만한', 124.7, 126.1, 1],
#  ['메세지를', 126.1, 126.8, 1],
#  ['잡혀', 126.8, 127.1, 1],
#  ['있습니다', 127.1, 127.3, 1],
#  ['인도적', 127.3, 128.6, 1],
#  ['차원에서', 128.6, 128.8, 1],
#  ['대북지원을', 128.8, 129.8, 1],
#  ['확실히', 129.8, 130.3, 1],
#  ['보장하고', 130.3, 130.8, 1],
#  ['미국인의', 130.8, 131.9, 1],
#  ['북한', 131.9, 132.6, 1],
#  ['여행', 132.6, 133.0, 1],
#  ['금지조치를', 133.0, 133.7, 1],
#  ['재검토하겠다고', 133.7, 134.9, 1],
#  ['밝혔다', 134.9, 135.1, 1],
#  ['입니다', 135.1, 135.7, 1],
#  ['남궁민', 135.7, 137.6, 1],
#  ['사이를', 137.6, 137.9, 1],
#  ['갈라놓을', 137.9, 138.4, 1],
#  ['어떤지', 138.4, 138.8, 1],
#  ['난', 138.8, 139.0, 1],
#  ['70년에', 139.0, 139.6, 1],
#  ['적대감을', 139.6, 140.4, 1],
#  ['뛰어넘을', 140.4, 141.2, 1],
#  ['수', 141.2, 141.3, 1],
#  ['있도록', 141.3, 141.7, 1],
#  ['북한과', 141.7, 143.0, 1],
#  ['확장하겠다는', 143.0, 143.8, 1],
#  ['운동했습니다', 143.8, 145.0, 1],
#  ['그동안은', 145.0, 146.5, 1],
#  ['엄격한', 146.5, 147.1, 1],
#  ['대북제재', 147.1, 147.7, 1],
#  ['방침을', 147.7, 148.3, 1],
#  ['고수했던', 148.3, 148.9, 1],
#  ['미국이', 148.9, 149.4, 1],
#  ['유화책을', 149.4, 151.0, 1],
#  ['제시한', 151.0, 151.4, 1],
#  ['것입니다', 151.4, 151.9, 1],
#  ['미국', 151.9, 153.1, 1],
#  ['정부가', 153.1, 153.5, 1],
#  ['인도적', 153.5, 154.6, 1],
#  ['차원에서', 154.6, 154.8, 1],
#  ['대북지원을', 154.8, 156.1, 1],
#  ['북미대화를', 156.1, 157.9, 1],
#  ['다시', 157.9, 158.5, 1],
#  ['진전', 158.5, 159.1, 1],
#  ['시키겠다는', 159.1, 159.8, 1],
#  ['강한', 159.8, 160.4, 1],
#  ['의지를', 160.4, 160.7, 1],
#  ['밝힌', 160.7, 161.5, 1],
#  ['것으로', 161.5, 162.0, 1],
#  ['해석된다', 162.0, 162.9, 1],
#  ['북한이', 162.9, 164.2, 1],
#  ['어떤', 164.2, 164.5, 1],
#  ['반응을', 164.5, 164.8, 1],
#  ['보이는', 164.8, 165.3, 1],
#  ['양에', 165.3, 165.5, 1],
#  ['따라', 165.5, 165.8, 1],
#  ['행동할', 165.8, 166.4, 1],
#  ['교착상태를', 166.4, 167.8, 1],
#  ['보이던', 167.8, 168.3, 1],
#  ['대화가', 168.3, 169.4, 1],
#  ['재개', 169.4, 170.2, 1],
#  ['될', 170.2, 170.3, 1],
#  ['가능성도', 170.3, 171.0, 1],
#  ['충분히', 171.0, 171.6, 1],
#  ['있어', 171.6, 171.9, 1],
#  ['보입니다', 171.9, 172.2, 1],
#  ['오늘과', 172.2, 173.7, 1],
#  ['내일', 173.7, 174.1, 1],
#  ['추석', 174.1, 174.9, 1],
#  ['대표회의', 174.9, 175.8, 1],
#  ['한미워킹그룹', 175.8, 177.3, 1],
#  ['2차', 177.3, 177.5, 1],
#  ['회의를', 177.5, 177.9, 1],
#  ['통해', 177.9, 178.2, 1],
#  ['한미', 178.2, 178.7, 1],
#  ['양국이', 178.7, 179.1, 1],
#  ['국민', 179.1, 179.9, 1],
#  ['새로운', 180.3, 181.4, 1],
#  ['돌파구를', 181.4, 182.0, 1],
#  ['마지막에', 182.0, 182.9, 1],
#  ['바랍니다', 182.9, 183.5, 1],
#  ['미국식이', 183.5, 185.6, 1],
#  ['인도적', 185.6, 186.3, 1],
#  ['지원에', 186.3, 186.7, 1],
#  ['체제를', 186.7, 187.5, 1],
#  ['식사하면서', 187.5, 188.1, 1],
#  ['남북', 188.1, 188.7, 1],
#  ['교류', 188.7, 189.0, 1],
#  ['해도', 189.0, 189.2, 1],
#  ['탄력이', 189.2, 190.2, 1],
#  ['붙을', 190.2, 190.6, 1],
#  ['것으로', 190.6, 190.9, 1],
#  ['예상됩니다', 190.9, 191.8, 1],
#  ['26일', 191.8, 194.1, 1],
#  ['열리는', 194.1, 195.1, 1],
#  ['남북', 195.1, 196.5, 1],
#  ['철도', 196.5, 197.4, 1],
#  ['착공시기', 197.4, 198.6, 1],
#  ['남북교류를', 198.6, 199.6, 1],
#  ['확대하고', 199.6, 200.4, 1],
#  ['북미대화', 200.4, 201.6, 1],
#  ['진전을', 201.6, 202.1, 1],
#  ['가져오는', 202.1, 202.7, 1],
#  ['계기가', 202.7, 203.1, 1],
#  ['되기를', 203.1, 203.4, 1],
#  ['바랍니다', 203.4, 203.8, 1],
#  ['미국', 203.8, 206.5, 1],
#  ['중앙은행이', 206.5, 207.2, 1],
#  ['오늘', 207.2, 207.6, 1],
#  ['새벽', 207.6, 208.2, 1],
#  ['기준', 208.2, 208.9, 1],
#  ['금리를', 208.9, 209.5, 1],
#  ['또', 209.5, 209.7, 1],
#  ['인상했습니다', 209.7, 210.4, 1],
#  ['월드', 210.4, 211.7, 1],
#  ['엄마는', 211.7, 212.7, 1],
#  ['벌써', 212.7, 212.8, 1],
#  ['네', 212.8, 213.3, 1],
#  ['번째', 213.3, 213.8, 1],
#  ['기준', 213.8, 214.3, 1],
#  ['금리', 214.3, 214.7, 1],
#  ['인상', 214.7, 215.1, 1],
#  ['입니다', 215.1, 215.5, 1],
#  ['미국과', 215.5, 217.2, 1],
#  ['우리나라의', 217.2, 217.6, 1],
#  ['기준', 217.6, 218.8, 1],
#  ['금리격차', 218.8, 219.5, 1],
#  ['넣어서', 219.5, 220.2, 1],
#  ['벌어졌습니다', 220.2, 220.9, 1],
#  ['미국', 220.9, 222.3, 1],
#  ['금리', 222.3, 222.6, 1],
#  ['인상은', 222.6, 223.2, 1],
#  ['우리', 223.2, 223.6, 1],
#  ['경제의', 223.6, 224.2, 1],
#  ['여러', 224.2, 224.6, 1],
#  ['측면에서', 224.6, 225.0, 1],
#  ['영향을', 225.0, 226.5, 1],
#  ['미치게', 226.5, 227.0, 1],
#  ['됩니다', 227.0, 227.2, 1],
#  ['물론', 227.2, 228.7, 1],
#  ['당장은', 228.7, 229.3, 1],
#  ['우리', 229.3, 229.6, 1],
#  ['경제에', 229.6, 230.2, 1],
#  ['큰', 230.2, 230.3, 1],
#  ['영향은', 230.3, 231.0, 1],
#  ['없을', 231.0, 231.3, 1],
#  ['것이란', 231.3, 231.8, 1],
#  ['전망이', 231.8, 232.4, 1],
#  ['우세하다', 232.4, 232.5, 1],
#  ['그러나', 232.5, 233.9, 1],
#  ['외국인자금', 233.9, 234.8, 1],
#  ['유출과', 234.8, 235.5, 1],
#  ['이로', 235.5, 235.8, 1],
#  ['인해', 235.8, 236.1, 1],
#  ['금융시장이', 236.1, 237.8, 1],
#  ['불안해질', 237.8, 238.6, 1],
#  ['가능성을', 238.6, 239.4, 1],
#  ['배제할', 239.4, 239.9, 1],
#  ['수', 239.9, 240.1, 1],
#  ['없', 240.1, 240.3, 1],
#  ['네', 0.4, 6.9, 1],
#  ['반갑습니다', 6.9, 7.2, 1],
#  ['제', 7.2, 7.8, 1],
#  ['115차', 7.8, 8.7, 1],
#  ['정책조정회의', 8.7, 9.5, 1],
#  ['를', 9.5, 9.9, 1],
#  ['원내대표에', 9.9, 11.0, 1],
#  ['모두', 11.0, 11.2, 1],
#  ['바로', 11.2, 11.5, 1],
#  ['시작하겠습니다', 11.5, 12.0, 1],
#  ['11', 12.0, 15.5, 1],
#  ['12', 15.5, 16.3, 1],
#  ['월', 16.3, 16.6, 1],
#  ['임시', 16.6, 17.1, 1],
#  ['이렇게', 17.1, 17.5, 1],
#  ['분위기가', 17.5, 18.2, 1],
#  ['아', 18.2, 18.9, 1],
#  ['이제', 18.9, 19.4, 1],
#  ['일주일', 19.4, 19.7, 1],
#  ['앞으로', 19.7, 20.2, 1],
#  ['다가왔습니다', 20.2, 20.6, 1],
#  ['여야가', 20.6, 22.6, 1],
#  ['민생법안', 22.6, 23.6, 1],
#  ['처리를', 23.6, 24.1, 1],
#  ['위해', 24.1, 24.3, 1],
#  ['논의', 24.3, 25.3, 1],
#  ['속도를', 25.3, 26.1, 1],
#  ['더', 26.1, 26.3, 1],
#  ['내야겠습니다', 26.3, 26.8, 1],
#  ['꼭', 26.8, 28.6, 1],
#  ['처리해야', 28.6, 29.3, 1],
#  ['할', 29.3, 29.6, 1],
#  ['과제는', 29.6, 30.5, 1],
#  ['6300번', 30.5, 31.9, 1],
#  ['산업안전보건법', 31.9, 33.6, 1],
#  ['입니다', 33.6, 34.0, 1],
#  ['6003번', 34.0, 36.0, 1],
#  ['오늘', 36.0, 36.3, 1],
#  ['의', 36.3, 36.8, 1],
#  ['연애', 36.8, 37.0, 1],
#  ['법안소위에서', 37.0, 38.1, 1],
#  ['눈이', 38.1, 38.8, 1],
#  ['될', 38.8, 39.1, 1],
#  ['예정입니다', 39.1, 39.8, 1],
#  ['오늘', 39.8, 40.7, 1],
#  ['합의가', 40.7, 41.3, 1],
#  ['이루어지지', 41.3, 41.9, 1],
#  ['않을', 41.9, 42.2, 1],
#  ['경우', 42.2, 42.6, 1],
#  ['27번의', 42.6, 44.2, 1],
#  ['처리가', 44.2, 44.9, 1],
#  ['사실상', 44.9, 45.5, 1],
#  ['어렵습니다', 45.5, 46.2, 1],
#  ['자유한국당', 46.2, 48.0, 1],
#  ['도', 48.0, 48.2, 1],
#  ['아이들이', 48.2, 49.1, 1],
#  ['하는', 49.1, 49.3, 1],
#  ['마음이', 49.3, 49.8, 1],
#  ['조금이라도', 49.8, 50.4, 1],
#  ['있다면', 50.4, 50.8, 1],
#  ['6003번', 50.8, 52.2, 1],
#  ['노니', 52.2, 52.5, 1],
#  ['접속', 52.5, 53.5, 1],
#  ['구매합니다', 53.5, 54.3, 1],
#  ['지난번', 54.3, 56.6, 1],
#  ['정기국회', 56.6, 57.2, 1],
#  ['때처럼', 57.2, 57.7, 1],
#  ['법원', 57.7, 59.6, 1],
#  ['처리를', 59.6, 60.2, 1],
#  ['연', 60.4, 60.9, 1],
#  ['시키려는', 60.9, 61.8, 1],
#  ['무슨', 61.8, 62.5, 1],
#  ['국민이', 62.5, 63.7, 1],
#  ['용납하지', 63.7, 64.6, 1],
#  ['않을', 64.6, 64.9, 1],
#  ['것입니다', 64.9, 65.2, 1],
#  ['우리', 65.2, 66.9, 1],
#  ['다음은', 66.9, 67.3, 1],
#  ['오늘', 67.3, 68.0, 1],
#  ['처리될', 68.0, 69.3, 1],
#  ['수', 69.3, 69.4, 1],
#  ['있도록', 69.4, 69.5, 1],
#  ['최선을', 69.5, 70.7, 1],
#  ['다해서', 70.7, 70.9, 1],
#  ['열린', 70.9, 71.6, 1],
#  ['자세로', 71.6, 71.8, 1],
#  ['소방서에', 71.8, 73.5, 1],
#  ['임하겠습니다', 73.5, 74.0, 1],
#  ['그러나', 74.0, 76.6, 1],
#  ['끝내', 76.6, 77.4, 1],
#  ['자유한국당이', 77.4, 78.6, 1],
#  ['반대한다면', 78.6, 79.8, 1],
#  ['패스트트랙을', 79.8, 82.6, 1],
#  ['통해', 82.6, 83.7, 1],
#  ['처리하는', 83.7, 85.6, 1],
#  ['방안을', 85.6, 86.2, 1],
#  ['추진', 86.2, 87.6, 1],
#  ['하겠습니다', 87.6, 88.2, 1],
#  ['위험의', 88.2, 90.0, 1],
#  ['외주화', 90.0, 90.0, 1],
#  ['를', 90.0, 90.6, 1],
#  ['막을', 90.6, 91.1, 1],
#  ['산업안전보건법', 91.1, 93.0, 1],
#  ['또', 93.0, 93.2, 1],
#  ['반드시', 93.2, 93.7, 1],
#  ['처리하겠습니다', 93.7, 94.4, 1],
#  ['더', 94.4, 97.1, 1],
#  ['이상', 97.1, 97.4, 1],
#  ['내몰리지', 97.4, 99.0, 1],
#  ['않기', 99.0, 99.3, 1],
#  ['위해서', 99.3, 99.7, 1],
#  ['필요한', 99.7, 100.0, 1],
#  ['법안입니다', 100.0, 100.5, 1],
#  ['다행히', 100.5, 102.0, 1],
#  ['어제', 102.0, 102.5, 1],
#  ['황영희', 102.5, 103.0, 1],
#  ['고용노동청', 103.0, 103.9, 1],
#  ['위해서', 103.9, 104.3, 1],
#  ['27일', 104.3, 105.1, 1],
#  ['본회의에서', 105.1, 105.6, 1],
#  ['산업안전보건법을', 105.6, 107.7, 1],
#  ['처리하기', 107.7, 108.4, 1],
#  ['여야간', 108.4, 109.2, 1],
#  ['의견이', 109.2, 110.1, 1],
#  ['모아졌다', 110.1, 110.5, 1],
#  ['습니다', 110.5, 111.0, 1],
#  ['앞으로', 111.0, 111.9, 1],
#  ['돈', 111.9, 112.0, 1],
#  ['이', 112.0, 112.1, 1],
#  ['과정에서', 112.1, 112.8, 1],
#  ['차질', 112.8, 113.4, 1],
#  ['없이', 113.4, 113.7, 1],
#  ['처리될', 113.7, 115.4, 1],
#  ['수', 115.4, 115.4, 1],
#  ['있도록', 115.4, 115.6, 1],
#  ['기도합니다', 115.6, 117.4, 1],
#  ['협상을', 120.4, 121.3, 1],
#  ['총괄하는', 121.3, 121.7, 1],
#  ['비건', 121.7, 122.5, 1],
#  ['미국', 122.5, 122.9, 1],
#  ['특별대표가', 122.9, 123.7, 1],
#  ['어제', 123.7, 124.0, 1],
#  ['방황하면서', 124.0, 124.7, 1],
#  ['주목할만한', 124.7, 126.1, 1],
#  ['메세지를', 126.1, 126.8, 1],
#  ['잡혀', 126.8, 127.1, 1],
#  ['있습니다', 127.1, 127.3, 1],
#  ['인도적', 127.3, 128.6, 1],
#  ['차원에서', 128.6, 128.8, 1],
#  ['대북지원을', 128.8, 129.8, 1],
#  ['확실히', 129.8, 130.3, 1],
#  ['보장하고', 130.3, 130.8, 1],
#  ['미국인의', 130.8, 131.9, 1],
#  ['북한', 131.9, 132.6, 1],
#  ['여행', 132.6, 133.0, 1],
#  ['금지조치를', 133.0, 133.7, 1],
#  ['재검토하겠다고', 133.7, 134.9, 1],
#  ['밝혔다', 134.9, 135.1, 1],
#  ['입니다', 135.1, 135.7, 1],
#  ['남궁민', 135.7, 137.6, 1],
#  ['사이를', 137.6, 137.9, 1],
#  ['갈라놓을', 137.9, 138.4, 1],
#  ['어떤지', 138.4, 138.8, 1],
#  ['난', 138.8, 139.0, 1],
#  ['70년에', 139.0, 139.6, 1],
#  ['적대감을', 139.6, 140.4, 1],
#  ['뛰어넘을', 140.4, 141.2, 1],
#  ['수', 141.2, 141.3, 1],
#  ['있도록', 141.3, 141.7, 1],
#  ['북한과', 141.7, 143.0, 1],
#  ['확장하겠다는', 143.0, 143.8, 1],
#  ['운동했습니다', 143.8, 145.0, 1],
#  ['그동안은', 145.0, 146.5, 1],
#  ['엄격한', 146.5, 147.1, 1],
#  ['대북제재', 147.1, 147.7, 1],
#  ['방침을', 147.7, 148.3, 1],
#  ['고수했던', 148.3, 148.9, 1],
#  ['미국이', 148.9, 149.4, 1],
#  ['유화책을', 149.4, 151.0, 1],
#  ['제시한', 151.0, 151.4, 1],
#  ['것입니다', 151.4, 151.9, 1],
#  ['미국', 151.9, 153.1, 1],
#  ['정부가', 153.1, 153.5, 1],
#  ['인도적', 153.5, 154.6, 1],
#  ['차원에서', 154.6, 154.8, 1],
#  ['대북지원을', 154.8, 156.1, 1],
#  ['북미대화를', 156.1, 157.9, 1],
#  ['다시', 157.9, 158.5, 1],
#  ['진전', 158.5, 159.1, 1],
#  ['시키겠다는', 159.1, 159.8, 1],
#  ['강한', 159.8, 160.4, 1],
#  ['의지를', 160.4, 160.7, 1],
#  ['밝힌', 160.7, 161.5, 1],
#  ['것으로', 161.5, 162.0, 1],
#  ['해석된다', 162.0, 162.9, 1],
#  ['북한이', 162.9, 164.2, 1],
#  ['어떤', 164.2, 164.5, 1],
#  ['반응을', 164.5, 164.8, 1],
#  ['보이는', 164.8, 165.3, 1],
#  ['양에', 165.3, 165.5, 1],
#  ['따라', 165.5, 165.8, 1],
#  ['행동할', 165.8, 166.4, 1],
#  ['교착상태를', 166.4, 167.8, 1],
#  ['보이던', 167.8, 168.3, 1],
#  ['대화가', 168.3, 169.4, 1],
#  ['재개', 169.4, 170.2, 1],
#  ['될', 170.2, 170.3, 1],
#  ['가능성도', 170.3, 171.0, 1],
#  ['충분히', 171.0, 171.6, 1],
#  ['있어', 171.6, 171.9, 1],
#  ['보입니다', 171.9, 172.2, 1],
#  ['오늘과', 172.2, 173.7, 1],
#  ['내일', 173.7, 174.1, 1],
#  ['추석', 174.1, 174.9, 1],
#  ['대표회의', 174.9, 175.8, 1],
#  ['한미워킹그룹', 175.8, 177.3, 1],
#  ['2차', 177.3, 177.5, 1],
#  ['회의를', 177.5, 177.9, 1],
#  ['통해', 177.9, 178.2, 1],
#  ['한미', 178.2, 178.7, 1],
#  ['양국이', 178.7, 179.1, 1],
#  ['국민', 179.1, 179.9, 1],
#  ['새로운', 180.3, 181.4, 1],
#  ['돌파구를', 181.4, 182.0, 1],
#  ['마지막에', 182.0, 182.9, 1],
#  ['바랍니다', 182.9, 183.5, 1],
#  ['미국식이', 183.5, 185.6, 1],
#  ['인도적', 185.6, 186.3, 1],
#  ['지원에', 186.3, 186.7, 1],
#  ['체제를', 186.7, 187.5, 1],
#  ['식사하면서', 187.5, 188.1, 1],
#  ['남북', 188.1, 188.7, 1],
#  ['교류', 188.7, 189.0, 1],
#  ['해도', 189.0, 189.2, 1],
#  ['탄력이', 189.2, 190.2, 1],
#  ['붙을', 190.2, 190.6, 1],
#  ['것으로', 190.6, 190.9, 1],
#  ['예상됩니다', 190.9, 191.8, 1],
#  ['26일', 191.8, 194.1, 1],
#  ['열리는', 194.1, 195.1, 1],
#  ['남북', 195.1, 196.5, 1],
#  ['철도', 196.5, 197.4, 1],
#  ['착공시기', 197.4, 198.6, 1],
#  ['남북교류를', 198.6, 199.6, 1],
#  ['확대하고', 199.6, 200.4, 1],
#  ['북미대화', 200.4, 201.6, 1],
#  ['진전을', 201.6, 202.1, 1],
#  ['가져오는', 202.1, 202.7, 1],
#  ['계기가', 202.7, 203.1, 1],
#  ['되기를', 203.1, 203.4, 1],
#  ['바랍니다', 203.4, 203.8, 1],
#  ['미국', 203.8, 206.5, 1],
#  ['중앙은행이', 206.5, 207.2, 1],
#  ['오늘', 207.2, 207.6, 1],
#  ['새벽', 207.6, 208.2, 1],
#  ['기준', 208.2, 208.9, 1],
#  ['금리를', 208.9, 209.5, 1],
#  ['또', 209.5, 209.7, 1],
#  ['인상했습니다', 209.7, 210.4, 1],
#  ['월드', 210.4, 211.7, 1],
#  ['엄마는', 211.7, 212.7, 1],
#  ['벌써', 212.7, 212.8, 1],
#  ['네', 212.8, 213.3, 1],
#  ['번째', 213.3, 213.8, 1],
#  ['기준', 213.8, 214.3, 1],
#  ['금리', 214.3, 214.7, 1],
#  ['인상', 214.7, 215.1, 1],
#  ['입니다', 215.1, 215.5, 1],
#  ...]

# %%
# CSV 파일로 저장
csv_file = "text/" + FILE_NAME + ".csv"
with open(csv_file, 'w', encoding='utf-8', newline='') as f:
    wr = csv.writer(f)
    wr.writerow(["word", "start_time", "end_time", "speaker_tag"])
    for words in words_array:
        wr.writerow(words)
